# %% [markdown]
# # Day 2 — Python for Network & System Security
#
# *Python for Security — 3-Day Intensive  |  Istidama Consulting*
#
# **DELTA Stage:** Learn + Test
#
# ### Day Overview
# Day 2 moves from text files to live systems: HTTP requests, structured network logs, and read-only OS interaction. The day closes with an ethics briefing and a hands-on build lab where each learner ships one small, complete security tool of their choosing.
#
# Each day in this notebook is organized in two parts: **Techniques** (worked, runnable examples you read and run) followed by **Practice — Your Turn** (the floor/ceiling exercises you complete yourself, gathered at the end).
#
# ---

# %% [markdown]
# ## 2.1 Recap & Repo Check  *(15 min)*
#
# **Objective:** Surface and correct common Day 1 mistakes before building on them.
#
# **Steps:**
#
# 1. Quick show of hands on who finished each Day 1 deliverable.
# 2. Spot-check 2–3 repos and address the most common commit-hygiene or regex issue as a group.

# %% [markdown]
# ## 2.2 Techniques Demonstrated: HTTP Requests, CSV Parsing & OS Interaction  *(45 min — read along and run every cell)*
#
# **Objective:** See each core technique work end to end before applying it yourself in Practice.
#
# **What's demonstrated below, in order:**
#
# 1. Making an HTTP request with `requests.get()` and inspecting the response.
# 2. Looping over multiple URLs and flagging non-200 responses.
# 3. Reading a CSV with `csv.DictReader` and tallying a column with `Counter`.
# 4. Flagging rows that match a watchlist of values.
# 5. Listing running processes (with a safe fallback if `psutil` isn't installed).
# 6. Running a read-only command with `subprocess.run()`.
# 7. Hashing a file with `hashlib.sha256()` and comparing digests.
# 8. Checking whether a local port is open with `socket`.
#
# These are the exact techniques you'll apply yourself — against different data and targets — in the Practice section at the end of this notebook.

# %%
import requests  # third-party HTTP library

# Technique 1: make a request, inspect status_code / headers / text
demo_url = "https://httpbin.org/json"  # a public test endpoint returning JSON
response = requests.get(demo_url)  # issue an HTTP GET request

print("status code:", response.status_code)  # the numeric HTTP status returned
print("headers (subset):", dict(list(response.headers.items())[:3]))  # first 3 response headers as a dict
print("body preview:", response.text[:100])  # first 100 characters of the response body
# Out:
# status code: 200
# headers (subset): {'Date': 'Fri, 11 Sep 2026 23:51:56 GMT', 'Content-Type': 'application/json', 'Content-Length': '429'}
# body preview: {
#   "slideshow": {
#     "author": "Yours Truly",
#     "date": "date of publication",
#     "slides": [

# %%
# Technique 2: loop over multiple URLs, flag anything that isn't 200
demo_urls = [
    "https://httpbin.org/status/200",  # endpoint that always returns 200
    "https://httpbin.org/status/403",  # endpoint that always returns 403
    "https://httpbin.org/status/404",  # endpoint that always returns 404
]  # list of test endpoints to check

for u in demo_urls:  # loop over each URL
    r = requests.get(u)  # request the URL
    flag = "" if r.status_code == 200 else "  <-- FLAGGED"  # mark anything that isn't a 200 OK
    print(f"{u} -> {r.status_code}{flag}")  # print the URL, its status, and any flag
# Out:
# https://httpbin.org/status/200 -> 200
# https://httpbin.org/status/403 -> 403  <-- FLAGGED
# https://httpbin.org/status/404 -> 404  <-- FLAGGED

# %%
import csv  # standard library module for reading/writing CSV files
from collections import Counter  # Counter tallies hashable items and supports most_common()

# Demo setup: a small connections CSV, separate from the one you'll practice on later
demo_csv = """timestamp,src_ip,dst_port,protocol,bytes
2026-02-10T10:00:01,192.168.1.5,443,tcp,500
2026-02-10T10:00:04,192.168.1.6,53,udp,120
2026-02-10T10:00:09,192.168.1.5,443,tcp,600
2026-02-10T10:00:15,192.168.1.7,8080,tcp,300
2026-02-10T10:00:22,192.168.1.5,53,udp,90
"""  # multi-line CSV string: header row plus five sample connection rows

with open("demo_connections.csv", "w") as f:  # open (create/overwrite) the demo CSV for writing
    f.write(demo_csv)  # write the sample CSV text to disk

# Technique 3: csv.DictReader + Counter tally
with open("demo_connections.csv") as f:  # open the CSV for reading
    reader = csv.DictReader(f)  # parse rows into dicts keyed by the header column names
    protocol_counts = Counter(row["protocol"] for row in reader)  # tally how many rows use each protocol

print(protocol_counts)  # print the full Counter mapping
print("Most common:", protocol_counts.most_common(2))  # print the two most common protocols
# Out:
# Counter({'tcp': 3, 'udp': 2})
# Most common: [('tcp', 3), ('udp', 2)]

# %%
# Technique 4: flag rows whose value matches a watchlist set
watchlist_ports = {"53", "8080"}  # set of destination ports to watch for

with open("demo_connections.csv") as f:  # open the CSV for reading
    reader = csv.DictReader(f)  # parse rows into dicts keyed by the header column names
    for row in reader:  # iterate over each connection row
        if row["dst_port"] in watchlist_ports:  # check if this row's port is on the watchlist
            print("watchlist hit:", row)  # print the full matching row
# Out:
# watchlist hit: {'timestamp': '2026-02-10T10:00:04', 'src_ip': '192.168.1.6', 'dst_port': '53', 'protocol': 'udp', 'bytes': '120'}
# watchlist hit: {'timestamp': '2026-02-10T10:00:15', 'src_ip': '192.168.1.7', 'dst_port': '8080', 'protocol': 'tcp', 'bytes': '300'}
# watchlist hit: {'timestamp': '2026-02-10T10:00:22', 'src_ip': '192.168.1.5', 'dst_port': '53', 'protocol': 'udp', 'bytes': '90'}

# %%
# Technique 5: list running processes, with a safe fallback
try:
    import psutil  # optional third-party library for cross-platform process listing
    procs = [p.info for p in psutil.process_iter(["pid", "name"])][:5]  # grab pid/name for the first 5 processes
    for p in procs:  # loop over the collected process info dicts
        print(p)  # print each process's info
except ImportError:  # psutil isn't installed -- fall back to a shell command
    import subprocess  # standard library module for running external commands
    result = subprocess.run(["ps", "aux"], capture_output=True, text=True)  # run `ps aux` and capture its output
    for line in result.stdout.splitlines()[:5]:  # take the first 5 lines of output
        print(line)  # print each line
# Out:
# {'name': 'System Idle Process', 'pid': 0}
# {'name': 'System', 'pid': 4}
# {'name': '', 'pid': 140}
# {'name': 'Registry', 'pid': 184}
# {'name': 'IntelCpHDCPSvc.exe', 'pid': 608}

# %%
import subprocess  # standard library module for running external commands
import sys  # access the current Python interpreter portably
# Technique 6: run a safe, read-only command and capture its output
result = subprocess.run([sys.executable, "-c", "print('read-only demo command')"], capture_output=True, text=True)  # run a portable read-only command
print("return code:", result.returncode)  # 0 means the command succeeded
print("stdout:", result.stdout.strip())  # the command's captured output, trailing whitespace removed
# Out:
# return code: 0
# stdout: read-only demo command

# %%
import hashlib  # standard library module providing cryptographic hash functions

# Technique 7: hash a file, then verify it against a known digest
with open("demo_note.txt", "w") as f:  # open (create/overwrite) a demo text file
    f.write("Techniques demo file -- do not use for the hashing lab.\n")  # write a line of sample content

with open("demo_note.txt", "rb") as f:  # reopen the file in binary mode for hashing
    digest = hashlib.sha256(f.read()).hexdigest()  # compute the file's SHA-256 hash as a hex string
print("sha256:", digest)  # print the computed hash

known_good = digest  # pretend this hash was recorded earlier as the "known good" value
with open("demo_note.txt", "rb") as f:  # reopen the file again in binary mode
    recomputed = hashlib.sha256(f.read()).hexdigest()  # recompute the hash to check for changes
print("match?", recomputed == known_good)  # True if the file is unchanged since known_good was recorded
# Out:
# sha256: ed5a3b078c106a5349b2d9eaa68bd757f30acf2d808a48110d05461647abe313
# match? True

# %%
import socket  # standard library module for low-level networking

# Technique 8: check whether a port is open, LOCAL TARGET ONLY
def port_status(host, port, timeout=0.5):  # define a helper to check a single host:port
    sock = socket.socket(socket.AF_INET, socket.SOCK_STREAM)  # create a TCP/IPv4 socket
    sock.settimeout(timeout)  # cap how long to wait for a connection attempt
    result = sock.connect_ex((host, port))  # try to connect; returns 0 on success, an error code otherwise
    sock.close()  # release the socket
    return "open" if result == 0 else "closed"  # translate the result code into a human-readable status

for port in [22, 9999]:  # check a couple of sample ports
    print(f"127.0.0.1:{port} -> {port_status('127.0.0.1', port)}")  # print the status of each port
# Out:
# 127.0.0.1:22 -> closed
# 127.0.0.1:9999 -> closed

# %% [markdown]
# ## Examples
#
# Work through the practice items below using the techniques demonstrated above. Floor/ceiling markers tell you the minimum bar and the stretch goal.

# %% [markdown]
# ### 2.3 Practice: Networking with Python  *(30 min)*
#
# **Objective:** Make and interpret basic HTTP requests in Python.
#
# **Steps:**
#
# 1. Practice: hit 2–3 public test endpoints and print their status codes.
# 2. Discuss what a 200 vs. 403 vs. 404 vs. 500 response actually tells you.
#
# > **Floor:** script prints the status code and first 100 characters of the response body for a given URL.
# > **Ceiling:** script checks a list of URLs and flags any that don't return 200.

# %%
import requests  # third-party HTTP library

# Floor: fetch one URL and inspect the response
url = "https://httpbin.org/status/200"  # a public test endpoint that always returns 200
response = requests.get(url)  # issue an HTTP GET request

print("status code:", response.status_code)  # the numeric HTTP status returned
print("body preview:", response.text[:100])  # first 100 characters of the response body
# Out:
# status code: 200
# body preview:

# %%
# Ceiling: check a list of URLs and flag any that don't return 200
urls = [
    "https://httpbin.org/status/200",  # endpoint that always returns 200
    "https://httpbin.org/status/403",  # endpoint that always returns 403
    "https://httpbin.org/status/404",  # endpoint that always returns 404
    "https://httpbin.org/status/500",  # endpoint that always returns 500
]  # list of test endpoints to check
for u in urls:  # loop over each URL
    r = requests.get(u)  # request the URL
    flag = "" if r.status_code == 200 else "  <-- FLAGGED"  # mark anything that isn't a 200 OK
    print(f"{u} -> {r.status_code}{flag}")  # print the URL, its status, and any flag
# Out:
# https://httpbin.org/status/200 -> 200
# https://httpbin.org/status/403 -> 403  <-- FLAGGED
# https://httpbin.org/status/404 -> 404  <-- FLAGGED
# https://httpbin.org/status/500 -> 500  <-- FLAGGED

# %% [markdown]
# ### 2.4 Practice: Parsing Network/Traffic Log Data  *(45 min)*
#
# **Objective:** Turn a raw structured log into a short summary report.
#
# **Materials:** sample_traffic.csv (generated below)
#
# **Steps:**
#
# 1. Run the setup cell to generate sample_traffic.csv.
# 2. Read rows using the csv module.
# 3. Count connections per destination port.
# 4. Print a short report: top 5 ports by connection count.
#
# > **Floor:** report prints correctly for the sample file.
# > **Ceiling:** report also flags traffic to a short instructor-provided list of “suspicious” ports (e.g., 4444, 31337).

# %%
# Setup: generate a sample traffic CSV
traffic_csv = """timestamp,src_ip,dst_port,protocol,bytes
2026-01-04T09:00:01,10.0.0.5,443,tcp,1200
2026-01-04T09:00:05,10.0.0.6,80,tcp,850
2026-01-04T09:00:09,10.0.0.5,443,tcp,900
2026-01-04T09:00:12,10.0.0.9,4444,tcp,50
2026-01-04T09:00:14,10.0.0.5,22,tcp,300
2026-01-04T09:00:20,10.0.0.9,4444,tcp,60
2026-01-04T09:00:25,10.0.0.7,80,tcp,700
"""  # multi-line CSV string: header row plus seven sample traffic rows (includes port 4444 twice)

with open("sample_traffic.csv", "w") as f:  # open (create/overwrite) the traffic CSV for writing
    f.write(traffic_csv)  # write the sample CSV text to disk

# %%
import csv  # standard library module for reading/writing CSV files
from collections import Counter  # Counter tallies hashable items and supports most_common()

# Floor: top 5 destination ports by connection count
with open("sample_traffic.csv") as f:  # open the traffic CSV for reading
    reader = csv.DictReader(f)  # parse rows into dicts keyed by the header column names
    port_counts = Counter(row["dst_port"] for row in reader)  # tally how many connections hit each port

print("Top 5 ports:", port_counts.most_common(5))  # print the five most-hit destination ports
# Out:
# Top 5 ports: [('443', 2), ('80', 2), ('4444', 2), ('22', 1)]

# %%
# Ceiling: flag traffic to suspicious ports
suspicious_ports = {"4444", "31337"}  # set of ports commonly associated with malware C2
with open("sample_traffic.csv") as f:  # open the traffic CSV for reading
    reader = csv.DictReader(f)  # parse rows into dicts keyed by the header column names
    for row in reader:  # iterate over each traffic row
        if row["dst_port"] in suspicious_ports:  # check if this row's port is suspicious
            print("SUSPICIOUS:", row)  # print the full matching row
# Out:
# SUSPICIOUS: {'timestamp': '2026-01-04T09:00:12', 'src_ip': '10.0.0.9', 'dst_port': '4444', 'protocol': 'tcp', 'bytes': '50'}
# SUSPICIOUS: {'timestamp': '2026-01-04T09:00:20', 'src_ip': '10.0.0.9', 'dst_port': '4444', 'protocol': 'tcp', 'bytes': '60'}

# %% [markdown]
# ### 2.5 Practice: OS Interaction — Processes & Hashing  *(45 min)*
#
# **Objective:** Read OS-level information and verify file integrity from Python.
#
# **Steps:**
#
# 1. List a few running processes read-only (os or psutil, whichever is pre-installed).
# 2. Use subprocess.run() to call one safe, read-only command and capture its output.
# 3. Use hashlib.sha256() to hash a sample file and print the digest.
#
# > **Floor:** process list printed and a file hash computed.
# > **Ceiling:** script compares a file's hash against a known-good value and reports match/mismatch.
#
# *Discussion prompt: Why hash a file before and after a suspected incident? What does a mismatch tell an investigator?*

# %%
import subprocess  # standard library module for running external commands

# Floor part 1: list running processes (read-only)
try:
    import psutil  # optional third-party library for cross-platform process listing
    for p in psutil.process_iter(["pid", "name"]):  # iterate over all running processes
        print(p.info)  # print each process's pid and name
except ImportError:  # psutil isn't installed -- fall back to a shell command
    result = subprocess.run(["ps", "aux"], capture_output=True, text=True)  # run `ps aux` and capture its output
    for line in result.stdout.splitlines()[:10]:  # take the first 10 lines of output
        print(line)  # print each line
# Out:
# {'name': 'System Idle Process', 'pid': 0}
# {'name': 'System', 'pid': 4}
# {'name': '', 'pid': 140}
# {'name': 'Registry', 'pid': 184}
# {'name': 'IntelCpHDCPSvc.exe', 'pid': 608}
# {'name': 'smss.exe', 'pid': 624}
# {'name': 'csrss.exe', 'pid': 788}
# {'name': 'svchost.exe', 'pid': 812}
# {'name': 'RuntimeBroker.exe', 'pid': 1096}
# {'name': 'wininit.exe', 'pid': 1104}
# {'name': 'csrss.exe', 'pid': 1112}
# {'name': 'winlogon.exe', 'pid': 1200}
# {'name': 'services.exe', 'pid': 1224}
# {'name': 'LsaIso.exe', 'pid': 1264}
# {'name': 'lsass.exe', 'pid': 1272}
# {'name': 'svchost.exe', 'pid': 1332}
# {'name': 'svchost.exe', 'pid': 1412}
# {'name': 'WUDFHost.exe', 'pid': 1444}
# {'name': 'fontdrvhost.exe', 'pid': 1464}
# {'name': 'fontdrvhost.exe', 'pid': 1472}
# {'name': 'svchost.exe', 'pid': 1600}
# {'name': 'svchost.exe', 'pid': 1640}
# {'name': 'svchost.exe', 'pid': 1644}
# {'name': 'dwm.exe', 'pid': 1744}
# {'name': 'svchost.exe', 'pid': 1796}
# {'name': 'svchost.exe', 'pid': 1828}
# {'name': 'svchost.exe', 'pid': 1852}
# {'name': 'svchost.exe', 'pid': 1872}
# {'name': 'svchost.exe', 'pid': 1960}
# {'name': 'svchost.exe', 'pid': 1968}
# {'name': 'pet.exe', 'pid': 1980}
# {'name': 'brave.exe', 'pid': 2008}
# {'name': 'svchost.exe', 'pid': 2028}
# {'name': 'svchost.exe', 'pid': 2060}
# {'name': 'powershell.exe', 'pid': 2076}
# {'name': 'svchost.exe', 'pid': 2152}
# {'name': 'svchost.exe', 'pid': 2200}
# {'name': 'svchost.exe', 'pid': 2212}
# {'name': 'IntelCpHeciSvc.exe', 'pid': 2252}
# {'name': 'svchost.exe', 'pid': 2268}
# {'name': 'svchost.exe', 'pid': 2292}
# {'name': 'MicrosoftSecurityApp.exe', 'pid': 2324}
# {'name': 'svchost.exe', 'pid': 2332}
# {'name': 'Code.exe', 'pid': 2376}
# {'name': 'powershell.exe', 'pid': 2432}
# {'name': 'OmenCap.exe', 'pid': 2628}
# {'name': 'svchost.exe', 'pid': 2684}
# {'name': 'brave.exe', 'pid': 2760}
# {'name': 'NVDisplay.Container.exe', 'pid': 2796}
# {'name': 'svchost.exe', 'pid': 2884}
# {'name': 'OpenConsole.exe', 'pid': 2924}
# {'name': 'svchost.exe', 'pid': 2956}
# {'name': 'svchost.exe', 'pid': 2984}
# {'name': 'svchost.exe', 'pid': 3040}
# {'name': 'Code.exe', 'pid': 3116}
# {'name': 'MemCompression', 'pid': 3128}
# {'name': 'svchost.exe', 'pid': 3176}
# {'name': 'igfxCUIService.exe', 'pid': 3216}
# {'name': 'svchost.exe', 'pid': 3252}
# {'name': 'svchost.exe', 'pid': 3300}
# {'name': 'svchost.exe', 'pid': 3308}
# {'name': 'DiagsCap.exe', 'pid': 3320}
# {'name': 'AppHelperCap.exe', 'pid': 3340}
# {'name': 'TouchpointAnalyticsClientService.exe', 'pid': 3352}
# {'name': 'SysInfoCap.exe', 'pid': 3360}
# {'name': 'Slack.exe', 'pid': 3432}
# {'name': 'svchost.exe', 'pid': 3492}
# {'name': 'svchost.exe', 'pid': 3632}
# {'name': 'svchost.exe', 'pid': 3640}
# {'name': 'OfficeClickToRun.exe', 'pid': 3684}
# {'name': 'svchost.exe', 'pid': 3728}
# {'name': 'ShellHost.exe', 'pid': 3736}
# {'name': 'svchost.exe', 'pid': 3844}
# {'name': 'svchost.exe', 'pid': 3868}
# {'name': 'svchost.exe', 'pid': 4048}
# {'name': 'python.exe', 'pid': 4124}
# {'name': 'NVDisplay.Container.exe', 'pid': 4192}
# {'name': 'vmmemCmZygote', 'pid': 4252}
# {'name': 'WmiPrvSE.exe', 'pid': 4416}
# {'name': 'unsecapp.exe', 'pid': 4604}
# {'name': 'Slack.exe', 'pid': 4640}
# {'name': 'svchost.exe', 'pid': 4784}
# {'name': 'PhoneExperienceHost.exe', 'pid': 4864}
# {'name': 'svchost.exe', 'pid': 4876}
# {'name': 'conhost.exe', 'pid': 4896}
# {'name': 'python.exe', 'pid': 4940}
# {'name': 'svchost.exe', 'pid': 5112}
# {'name': 'svchost.exe', 'pid': 5132}
# {'name': 'svchost.exe', 'pid': 5164}
# {'name': 'svchost.exe', 'pid': 5168}
# {'name': 'ctfmon.exe', 'pid': 5172}
# {'name': 'ETDService.exe', 'pid': 5232}
# {'name': 'armsvc.exe', 'pid': 5272}
# {'name': 'svchost.exe', 'pid': 5412}
# {'name': 'svchost.exe', 'pid': 5420}
# {'name': 'OneApp.IGCC.WinService.exe', 'pid': 5456}
# {'name': 'Code.exe', 'pid': 5588}
# {'name': 'svchost.exe', 'pid': 5628}
# {'name': 'svchost.exe', 'pid': 5636}
# {'name': 'svchost.exe', 'pid': 5692}
# {'name': 'svchost.exe', 'pid': 5764}
# {'name': 'spoolsv.exe', 'pid': 5828}
# {'name': 'SecurityHealthSystray.exe', 'pid': 5860}
# {'name': 'nordvpn-service.exe', 'pid': 5872}
# {'name': 'nordsec-threatprotection-service.exe', 'pid': 5880}
# {'name': 'Code.exe', 'pid': 5888}
# {'name': 'svchost.exe', 'pid': 5940}
# {'name': 'Code.exe', 'pid': 6104}
# {'name': 'jhi_service.exe', 'pid': 6176}
# {'name': 'vmcompute.exe', 'pid': 6188}
# {'name': 'MpDefenderCoreService.exe', 'pid': 6204}
# {'name': 'MBAMService.exe', 'pid': 6224}
# {'name': 'esif_uf.exe', 'pid': 6232}
# {'name': 'bash.exe', 'pid': 6264}
# {'name': 'SecurityHealthService.exe', 'pid': 6328}
# {'name': 'NordUpdateService.exe', 'pid': 6372}
# {'name': 'RstMwService.exe', 'pid': 6396}
# {'name': 'RtkBtManServ.exe', 'pid': 6428}
# {'name': 'SECOMN64.exe', 'pid': 6436}
# {'name': 'RtkAudUService64.exe', 'pid': 6444}
# {'name': 'RuntimeBroker.exe', 'pid': 6468}
# {'name': 'sqlwriter.exe', 'pid': 6472}
# {'name': 'svchost.exe', 'pid': 6504}
# {'name': 'svchost.exe', 'pid': 6520}
# {'name': 'LMS.exe', 'pid': 6536}
# {'name': 'vmware-authd.exe', 'pid': 6544}
# {'name': 'svchost.exe', 'pid': 6580}
# {'name': 'svchost.exe', 'pid': 6636}
# {'name': 'XtuService.exe', 'pid': 6644}
# {'name': 'vmnat.exe', 'pid': 6660}
# {'name': 'MsMpEng.exe', 'pid': 6668}
# {'name': 'vmware-usbarbitrator64.exe', 'pid': 6696}
# {'name': 'wslservice.exe', 'pid': 6704}
# {'name': 'svchost.exe', 'pid': 6732}
# {'name': 'vmnetdhcp.exe', 'pid': 6772}
# {'name': 'svchost.exe', 'pid': 6824}
# {'name': 'ETDCtrl.exe', 'pid': 6940}
# {'name': 'svchost.exe', 'pid': 7124}
# {'name': 'msdtc.exe', 'pid': 7188}
# {'name': 'BridgeCommunication.exe', 'pid': 7320}
# {'name': 'svchost.exe', 'pid': 7552}
# {'name': 'brave.exe', 'pid': 7680}
# {'name': 'AggregatorHost.exe', 'pid': 8068}
# {'name': 'dllhost.exe', 'pid': 8108}
# {'name': 'sihost.exe', 'pid': 8280}
# {'name': 'Code.exe', 'pid': 8348}
# {'name': 'svchost.exe', 'pid': 8400}
# {'name': 'svchost.exe', 'pid': 8408}
# {'name': 'Code.exe', 'pid': 8488}
# {'name': 'Slack.exe', 'pid': 8504}
# {'name': 'svchost.exe', 'pid': 8508}
# {'name': 'NgcIso.exe', 'pid': 8608}
# {'name': 'svchost.exe', 'pid': 8672}
# {'name': 'svchost.exe', 'pid': 8676}
# {'name': 'Slack.exe', 'pid': 8736}
# {'name': 'igfxEM.exe', 'pid': 8764}
# {'name': 'svchost.exe', 'pid': 8808}
# {'name': 'taskhostw.exe', 'pid': 8884}
# {'name': 'SystemSettings.exe', 'pid': 8904}
# {'name': 'OpenConsole.exe', 'pid': 9000}
# {'name': 'bash.exe', 'pid': 9028}
# {'name': 'explorer.exe', 'pid': 9060}
# {'name': 'Code.exe', 'pid': 9140}
# {'name': 'svchost.exe', 'pid': 9268}
# {'name': 'conhost.exe', 'pid': 9312}
# {'name': 'NetworkCap.exe', 'pid': 9364}
# {'name': 'python.exe', 'pid': 9384}
# {'name': 'brave.exe', 'pid': 9432}
# {'name': 'CrossDeviceResume.exe', 'pid': 9460}
# {'name': 'svchost.exe', 'pid': 9468}
# {'name': 'svchost.exe', 'pid': 9636}
# {'name': 'svchost.exe', 'pid': 9792}
# {'name': 'CrossDeviceService.exe', 'pid': 9892}
# {'name': 'svchost.exe', 'pid': 9908}
# {'name': 'Code.exe', 'pid': 10028}
# {'name': 'svchost.exe', 'pid': 10052}
# {'name': 'svchost.exe', 'pid': 10084}
# {'name': 'SearchHost.exe', 'pid': 10560}
# {'name': 'StartMenuExperienceHost.exe', 'pid': 10596}
# {'name': 'svchost.exe', 'pid': 10768}
# {'name': 'WidgetBoard.exe', 'pid': 10804}
# {'name': 'powershell.exe', 'pid': 10844}
# {'name': 'RuntimeBroker.exe', 'pid': 10912}
# {'name': 'Code.exe', 'pid': 10924}
# {'name': 'svchost.exe', 'pid': 10968}
# {'name': 'Code.exe', 'pid': 11352}
# {'name': 'svchost.exe', 'pid': 11588}
# {'name': 'msedgewebview2.exe', 'pid': 11872}
# {'name': 'msedgewebview2.exe', 'pid': 12020}
# {'name': 'svchost.exe', 'pid': 12232}
# {'name': 'OpenConsole.exe', 'pid': 12256}
# {'name': 'msedgewebview2.exe', 'pid': 12440}
# {'name': 'msedgewebview2.exe', 'pid': 12448}
# {'name': 'msedgewebview2.exe', 'pid': 12616}
# {'name': 'msedgewebview2.exe', 'pid': 12712}
# {'name': 'LockApp.exe', 'pid': 12776}
# {'name': 'svchost.exe', 'pid': 12924}
# {'name': 'conhost.exe', 'pid': 13144}
# {'name': 'UserOOBEBroker.exe', 'pid': 13148}
# {'name': 'conhost.exe', 'pid': 13184}
# {'name': 'svchost.exe', 'pid': 13288}
# {'name': 'RuntimeBroker.exe', 'pid': 13644}
# {'name': 'RuntimeBroker.exe', 'pid': 13836}
# {'name': 'SearchIndexer.exe', 'pid': 13860}
# {'name': 'Code.exe', 'pid': 13916}
# {'name': 'svchost.exe', 'pid': 14116}
# {'name': 'WidgetService.exe', 'pid': 14248}
# {'name': 'svchost.exe', 'pid': 14284}
# {'name': 'DefenderSessionHelper.exe', 'pid': 14596}
# {'name': 'svchost.exe', 'pid': 14620}
# {'name': 'SDXHelper.exe', 'pid': 14636}
# {'name': 'brave.exe', 'pid': 14720}
# {'name': 'Malwarebytes.exe', 'pid': 14844}
# {'name': 'TextInputHost.exe', 'pid': 14864}
# {'name': 'Code.exe', 'pid': 14924}
# {'name': 'MicrosoftStartFeedProvider.exe', 'pid': 15588}
# {'name': 'svchost.exe', 'pid': 15812}
# {'name': 'BraveCrashHandler64.exe', 'pid': 16100}
# {'name': 'NisSrv.exe', 'pid': 16248}
# {'name': 'BraveCrashHandler.exe', 'pid': 16324}
# {'name': 'ApplicationFrameHost.exe', 'pid': 16408}
# {'name': 'svchost.exe', 'pid': 16420}
# {'name': 'Slack.exe', 'pid': 16512}
# {'name': 'Slack.exe', 'pid': 16520}
# {'name': 'Slack.exe', 'pid': 16576}
# {'name': 'RuntimeBroker.exe', 'pid': 16836}
# {'name': 'jusched.exe', 'pid': 17132}
# {'name': 'RtkAudUService64.exe', 'pid': 17144}
# {'name': 'Code.exe', 'pid': 17160}
# {'name': 'AdobeCollabSync.exe', 'pid': 17244}
# {'name': 'AdobeCollabSync.exe', 'pid': 17300}
# {'name': 'brave.exe', 'pid': 17412}
# {'name': 'brave.exe', 'pid': 17428}
# {'name': 'Code.exe', 'pid': 17532}
# {'name': 'OpenConsole.exe', 'pid': 17560}
# {'name': 'brave.exe', 'pid': 17588}
# {'name': 'brave.exe', 'pid': 17660}
# {'name': 'brave.exe', 'pid': 17668}
# {'name': 'brave.exe', 'pid': 17708}
# {'name': 'brave.exe', 'pid': 17752}
# {'name': 'brave.exe', 'pid': 17944}
# {'name': 'MbamBgNativeMsg.exe', 'pid': 17960}
# {'name': 'conhost.exe', 'pid': 18076}
# {'name': 'brave.exe', 'pid': 18176}
# {'name': 'brave.exe', 'pid': 18184}
# {'name': 'brave.exe', 'pid': 18220}
# {'name': 'cmd.exe', 'pid': 18228}
# {'name': 'AppActions.exe', 'pid': 18480}
# {'name': 'brave.exe', 'pid': 18540}
# {'name': 'brave.exe', 'pid': 18560}
# {'name': 'WmiPrvSE.exe', 'pid': 18648}
# {'name': 'brave.exe', 'pid': 18760}
# {'name': 'brave.exe', 'pid': 18768}
# {'name': 'brave.exe', 'pid': 19064}
# {'name': 'brave.exe', 'pid': 19240}

# %%
import hashlib  # standard library module providing cryptographic hash functions

# Setup: a sample file to hash
with open("sample_file.txt", "w") as f:  # open (create/overwrite) the sample file for writing
    f.write("This is a sample file for hashing practice.\n")  # write a line of sample content

# Floor part 2: hash sample_file.txt with sha256
with open("sample_file.txt", "rb") as f:  # reopen the file in binary mode for hashing
    digest = hashlib.sha256(f.read()).hexdigest()  # compute the file's SHA-256 hash as a hex string
print("sha256:", digest)  # print the computed hash
# Out:
# sha256: 07a2b73c916791807f45ca6aa40cd1b8ed96b2439e31a47f793e0bdc45976f01

# %%
# Ceiling: compare against a known-good hash
known_good_hash = digest  # reuse the hash computed in the previous cell as the "known good" value

with open("sample_file.txt", "rb") as f:  # reopen the file in binary mode for hashing
    recomputed = hashlib.sha256(f.read()).hexdigest()  # recompute the hash to check for changes

print("recomputed:", recomputed)  # print the freshly computed hash
print("match?", recomputed == known_good_hash)  # True if the file is unchanged since known_good_hash was recorded
# Out:
# recomputed: 07a2b73c916791807f45ca6aa40cd1b8ed96b2439e31a47f793e0bdc45976f01
# match? True

# %% [markdown]
# ## 2.6 Ethics & Authorized-Use Briefing  *(15 min — required before 2.7)*
#
# **Objective:** Set explicit boundaries before learners build anything that probes or scans.
#
# **Steps:**
#
# 1. State the rule plainly: these tools are only ever run against systems you own or are explicitly authorized to test.
# 2. Confirm the classroom exercises target only instructor-provided sample data and local test targets — never live third-party systems.
# 3. Be ready to name a real scenario where running this without authorization would be illegal or unethical.
#
# *Instructor note: Do not move on to 2.7 until this briefing has landed with the whole room, including the remote stream.*

# %% [markdown]
# ### 2.7 Practice: Build Lab — Choose Your Tool  *(90 min)*
#
# **Objective:** Build one small, complete security tool end to end.
#
# **Steps:**
#
# 1. Peer review: pair up, trade scripts, and leave two comments each — one compliment, one suggestion.
#
# **Learner picks ONE:**
#
# - Hash Verifier — floor: verify a single file's hash against a provided value; ceiling: verify a whole directory and report any mismatches.
# - Log Anomaly Flagger — floor: flag lines matching a keyword list; ceiling: flag any IP exceeding a failed-attempt threshold.
# - Basic Port Scanner (local test target only) — floor: check a small fixed list of ports against a provided local test address; ceiling: scan a small range and report open/closed cleanly.

# %%
import hashlib
import os

# 1. Function Definitions[cite: 1]
def verify_file(path, expected_hash):
    """Return True if path's sha256 matches expected_hash."""
    with open(path, "rb") as f:
        actual_hash = hashlib.sha256(f.read()).hexdigest()
    return actual_hash == expected_hash

def verify_directory(dir_path, expected_hashes: dict):
    """expected_hashes maps filename -> expected sha256. Print mismatches."""
    for filename, expected_hash in expected_hashes.items():
        path = os.path.join(dir_path, filename)
        
        if not os.path.isfile(path):
            print(f"MISSING: {filename}")
        elif not verify_file(path, expected_hash):
            print(f"MISMATCH: {filename}")
        else:
            print(f"OK: {filename}")


# 2. Testing Environment Setup
# Create a safe, original file
with open("system_core.dll", "w") as f:
    f.write("Safe and original content")

# Create a compromised file with injected malicious content
with open("config.ini", "w") as f:
    f.write("Malicious content injected by attacker!")

# Calculate the original hash of the safe file (to use as a baseline reference)
with open("system_core.dll", "rb") as f:
    original_hash = hashlib.sha256(f.read()).hexdigest()


# 3. Expected Hashes Database (Dictionary)
# Assume these are the baseline hashes we recorded earlier when the system was secure
known_good_hashes = {
    "system_core.dll": original_hash,  # Expected valid hash
    "config.ini": original_hash,       # Assuming the original hash matched, but it was altered
    "passwords.txt": "random_hash_123" # File does not exist at all in our folder
}


# 4. Running the Tool and Generating the Report
print("--- Security Integrity Report ---")
# "." means scanning the current working directory
verify_directory(".", known_good_hashes)
print("---------------------------------")
# Out:
# --- Security Integrity Report ---
# OK: system_core.dll
# MISMATCH: config.ini
# MISSING: passwords.txt
# ---------------------------------

# %%
import re
from collections import Counter

# 1. Function Definitions[cite: 1]
def flag_keywords(filename, keywords):
    """Scan the log file for Indicators of Compromise (IOCs) based on a keyword watchlist."""
    print("--- Floor: Keyword Anomaly Detection ---")
    with open(filename) as f:  # Open the log file in read mode
        for line in f:  # Iterate through the file line by line
            # Check if any suspicious keyword exists in the current log entry
            if any(keyword in line for keyword in keywords):
                print(f"ALERT (Keyword Match): {line.strip()}")

def flag_ip_threshold(filename, threshold):
    """Identify potential brute-force attacks by flagging IPs that exceed a failed login threshold."""
    print(f"\n--- Ceiling: Brute-Force Threshold Detection (>{threshold} attempts) ---")
    ip_counts = Counter()  # Initialize a counter for failed authentication attempts
    
    with open(filename) as f:
        for line in f:
            # Filter for failed authentication events
            if "Failed password" in line:
                # Extract the source IP address using a regular expression
                match = re.search(r"\d+\.\d+\.\d+\.\d+", line)
                if match:
                    ip_counts[match.group()] += 1  # Increment the threat tally for this IP

    # Evaluate the gathered threat intelligence against the defined threshold
    for ip, count in ip_counts.items():
        if count > threshold:
            print(f"FLAGGED IP: {ip} -> {count} failed attempts detected!")


# 2. Testing Environment Setup (Simulating a server log)
# Generate a dummy log file containing both normal traffic and malicious activities
log_content = """Jan 10 14:01:00 srv sshd: Accepted password for user1 from 192.168.1.50
Jan 10 14:02:15 srv sshd: Failed password for root from 203.0.113.42
Jan 10 14:02:17 srv sshd: Failed password for root from 203.0.113.42
Jan 10 14:02:19 srv sshd: Failed password for admin from 203.0.113.42
Jan 10 14:03:00 srv sudo: user1 : command not allowed ; TTY=pts/0 ; PWD=/home/user1 ; USER=root ; COMMAND=/bin/su
Jan 10 14:05:22 srv sshd: Failed password for root from 198.51.100.7
Jan 10 14:05:25 srv sshd: Failed password for root from 203.0.113.42
"""
with open("simulated_server.log", "w") as f:
    f.write(log_content)


# 3. Running the Tool and Generating the Report
# Define our watchlist of suspicious terms (e.g., privilege escalation attempts)
watchlist = ["command not allowed", "unauthorized", "Accepted password for root"]

# Execute both analysis functions on our simulated log
flag_keywords("simulated_server.log", watchlist)

# We set the threshold to 2, meaning 3 or more fails will trigger the alert
flag_ip_threshold("simulated_server.log", threshold=2)
# Out:
# --- Floor: Keyword Anomaly Detection ---
# ALERT (Keyword Match): Jan 10 14:03:00 srv sudo: user1 : command not allowed ; TTY=pts/0 ; PWD=/home/user1 ; USER=root ; COMMAND=/bin/su
#
# --- Ceiling: Brute-Force Threshold Detection (>2 attempts) ---
# FLAGGED IP: 203.0.113.42 -> 4 failed attempts detected!

# %%
import socket  # standard library module for low-level networking

# Option C: Basic Port Scanner (LOCAL TEST TARGET ONLY -- e.g. "127.0.0.1")
import socket

def check_ports(host, ports):
    """Print open/closed for each port in a provided list on the target host."""
    print(f"--- Scanning fixed ports on {host} ---")
    
    for port in ports:
        # Create a TCP/IPv4 socket
        sock = socket.socket(socket.AF_INET, socket.SOCK_STREAM)
        
        # Set a timeout so the script doesn't hang on dropped packets
        sock.settimeout(0.5)
        
        # connect_ex returns 0 if successful, or an error indicator otherwise
        result = sock.connect_ex((host, port))
        
        # Always close the socket to free up system resources
        sock.close()
        
        # Evaluate the result
        status = "open" if result == 0 else "closed"
        print(f"{host}:{port} -> {status}")

# Execute the Floor requirement
target_ip = "10.10.1.19"
ports_to_check = [20, 5985 ,25,80,1801]

check_ports(target_ip, ports_to_check)
def scan_range(host, start_port, end_port):
    """Scan a contiguous range of ports and report open/closed cleanly."""
    print(f"\n--- Scanning port range {start_port}-{end_port} on {host} ---")
    
    # We use (end_port + 1) because Python's range() stops *before* the upper limit
    port_range = range(start_port, end_port + 1)
    
    # Reuse the function we already built
    check_ports(host, port_range)

# Execute the Ceiling requirement
scan_range("10.10.1.19", 25, 5985)
# Out:
# --- Scanning fixed ports on 10.10.1.19 ---
# 10.10.1.19:20 -> closed
# 10.10.1.19:5985 -> closed
# 10.10.1.19:25 -> closed
# 10.10.1.19:80 -> closed
# 10.10.1.19:1801 -> closed
#
# --- Scanning port range 25-5985 on 10.10.1.19 ---
# --- Scanning fixed ports on 10.10.1.19 ---
# 10.10.1.19:25 -> closed
# 10.10.1.19:26 -> closed
# 10.10.1.19:27 -> closed
# 10.10.1.19:28 -> closed
# 10.10.1.19:29 -> closed
# 10.10.1.19:30 -> closed
# 10.10.1.19:31 -> closed
# 10.10.1.19:32 -> closed
# 10.10.1.19:33 -> closed
# 10.10.1.19:34 -> closed
# 10.10.1.19:35 -> closed
# 10.10.1.19:36 -> closed
# 10.10.1.19:37 -> closed
# 10.10.1.19:38 -> closed
# 10.10.1.19:39 -> closed
# 10.10.1.19:40 -> closed
# 10.10.1.19:41 -> closed
# 10.10.1.19:42 -> closed
# 10.10.1.19:43 -> closed
# 10.10.1.19:44 -> closed
# 10.10.1.19:45 -> closed
# 10.10.1.19:46 -> closed
# 10.10.1.19:47 -> closed
# 10.10.1.19:48 -> closed
# 10.10.1.19:49 -> closed
# 10.10.1.19:50 -> closed
# 10.10.1.19:51 -> closed
# 10.10.1.19:52 -> closed
# 10.10.1.19:53 -> closed
# 10.10.1.19:54 -> closed
# 10.10.1.19:55 -> closed
# 10.10.1.19:56 -> closed
# 10.10.1.19:57 -> closed
# 10.10.1.19:58 -> closed
# 10.10.1.19:59 -> closed
# 10.10.1.19:60 -> closed
# 10.10.1.19:61 -> closed
# 10.10.1.19:62 -> closed
# 10.10.1.19:63 -> closed
# 10.10.1.19:64 -> closed
# 10.10.1.19:65 -> closed
# 10.10.1.19:66 -> closed
# 10.10.1.19:67 -> closed
# 10.10.1.19:68 -> closed
# 10.10.1.19:69 -> closed
# 10.10.1.19:70 -> closed
# 10.10.1.19:71 -> closed
# 10.10.1.19:72 -> closed
# 10.10.1.19:73 -> closed
# 10.10.1.19:74 -> closed
# 10.10.1.19:75 -> closed
# 10.10.1.19:76 -> closed
# 10.10.1.19:77 -> closed
# 10.10.1.19:78 -> closed
# 10.10.1.19:79 -> closed
# 10.10.1.19:80 -> closed
# 10.10.1.19:81 -> closed
# 10.10.1.19:82 -> closed
# 10.10.1.19:83 -> closed
# 10.10.1.19:84 -> closed
# 10.10.1.19:85 -> closed
# 10.10.1.19:86 -> closed
# 10.10.1.19:87 -> closed
# 10.10.1.19:88 -> closed
# 10.10.1.19:89 -> closed
# 10.10.1.19:90 -> closed
# 10.10.1.19:91 -> closed
# 10.10.1.19:92 -> closed
# 10.10.1.19:93 -> closed
# 10.10.1.19:94 -> closed
# 10.10.1.19:95 -> closed
# 10.10.1.19:96 -> closed
# 10.10.1.19:97 -> closed
# 10.10.1.19:98 -> closed
# 10.10.1.19:99 -> closed
# 10.10.1.19:100 -> closed
# 10.10.1.19:101 -> closed
# 10.10.1.19:102 -> closed
# 10.10.1.19:103 -> closed
# 10.10.1.19:104 -> closed
# 10.10.1.19:105 -> closed
# 10.10.1.19:106 -> closed
# 10.10.1.19:107 -> closed
# 10.10.1.19:108 -> closed
# 10.10.1.19:109 -> closed
# 10.10.1.19:110 -> closed
# 10.10.1.19:111 -> closed
# 10.10.1.19:112 -> closed
# 10.10.1.19:113 -> closed
# 10.10.1.19:114 -> closed
# 10.10.1.19:115 -> closed
# 10.10.1.19:116 -> closed
# 10.10.1.19:117 -> closed
# 10.10.1.19:118 -> closed
# 10.10.1.19:119 -> closed
# 10.10.1.19:120 -> closed
# 10.10.1.19:121 -> closed
# 10.10.1.19:122 -> closed
# 10.10.1.19:123 -> closed
# 10.10.1.19:124 -> closed
# 10.10.1.19:125 -> closed
# 10.10.1.19:126 -> closed
# 10.10.1.19:127 -> closed
# 10.10.1.19:128 -> closed
# 10.10.1.19:129 -> closed
# 10.10.1.19:130 -> closed
# 10.10.1.19:131 -> closed
# 10.10.1.19:132 -> closed
# 10.10.1.19:133 -> closed
# 10.10.1.19:134 -> closed
# 10.10.1.19:135 -> closed
# 10.10.1.19:136 -> closed
# 10.10.1.19:137 -> closed
# 10.10.1.19:138 -> closed
# 10.10.1.19:139 -> closed
# 10.10.1.19:140 -> closed
# 10.10.1.19:141 -> closed
# 10.10.1.19:142 -> closed
# 10.10.1.19:143 -> closed
# 10.10.1.19:144 -> closed
# 10.10.1.19:145 -> closed
# 10.10.1.19:146 -> closed
# 10.10.1.19:147 -> closed
# 10.10.1.19:148 -> closed
# 10.10.1.19:149 -> closed
# 10.10.1.19:150 -> closed
# 10.10.1.19:151 -> closed
# 10.10.1.19:152 -> closed
# 10.10.1.19:153 -> closed
# 10.10.1.19:154 -> closed
# 10.10.1.19:155 -> closed
# 10.10.1.19:156 -> closed
# 10.10.1.19:157 -> closed
# 10.10.1.19:158 -> closed
# 10.10.1.19:159 -> closed
# 10.10.1.19:160 -> closed
# 10.10.1.19:161 -> closed
# 10.10.1.19:162 -> closed
# 10.10.1.19:163 -> closed
# 10.10.1.19:164 -> closed
# 10.10.1.19:165 -> closed
# 10.10.1.19:166 -> closed
# 10.10.1.19:167 -> closed
# 10.10.1.19:168 -> closed
# 10.10.1.19:169 -> closed
# 10.10.1.19:170 -> closed
# 10.10.1.19:171 -> closed
# 10.10.1.19:172 -> closed
# 10.10.1.19:173 -> closed
# 10.10.1.19:174 -> closed
# 10.10.1.19:175 -> closed
# 10.10.1.19:176 -> closed
# 10.10.1.19:177 -> closed
# 10.10.1.19:178 -> closed
# 10.10.1.19:179 -> closed
# 10.10.1.19:180 -> closed
# 10.10.1.19:181 -> closed
# 10.10.1.19:182 -> closed
# 10.10.1.19:183 -> closed
# 10.10.1.19:184 -> closed
# 10.10.1.19:185 -> closed
# 10.10.1.19:186 -> closed
# 10.10.1.19:187 -> closed
# 10.10.1.19:188 -> closed
# 10.10.1.19:189 -> closed
# 10.10.1.19:190 -> closed
# 10.10.1.19:191 -> closed
# 10.10.1.19:192 -> closed
# 10.10.1.19:193 -> closed
# 10.10.1.19:194 -> closed
# 10.10.1.19:195 -> closed
# 10.10.1.19:196 -> closed
# 10.10.1.19:197 -> closed
# 10.10.1.19:198 -> closed
# 10.10.1.19:199 -> closed
# 10.10.1.19:200 -> closed
# 10.10.1.19:201 -> closed
# 10.10.1.19:202 -> closed
# 10.10.1.19:203 -> closed
# 10.10.1.19:204 -> closed
# 10.10.1.19:205 -> closed
# 10.10.1.19:206 -> closed
# 10.10.1.19:207 -> closed
# 10.10.1.19:208 -> closed
# 10.10.1.19:209 -> closed
# 10.10.1.19:210 -> closed
# 10.10.1.19:211 -> closed
# 10.10.1.19:212 -> closed
# 10.10.1.19:213 -> closed
# 10.10.1.19:214 -> closed
# 10.10.1.19:215 -> closed
# 10.10.1.19:216 -> closed
# 10.10.1.19:217 -> closed
# 10.10.1.19:218 -> closed
# 10.10.1.19:219 -> closed
# 10.10.1.19:220 -> closed
# 10.10.1.19:221 -> closed
# 10.10.1.19:222 -> closed
# 10.10.1.19:223 -> closed
# 10.10.1.19:224 -> closed
# 10.10.1.19:225 -> closed
# 10.10.1.19:226 -> closed
# 10.10.1.19:227 -> closed
# 10.10.1.19:228 -> closed
# 10.10.1.19:229 -> closed
# 10.10.1.19:230 -> closed
# 10.10.1.19:231 -> closed
# 10.10.1.19:232 -> closed
# 10.10.1.19:233 -> closed
# 10.10.1.19:234 -> closed
# 10.10.1.19:235 -> closed
# 10.10.1.19:236 -> closed
# 10.10.1.19:237 -> closed
# 10.10.1.19:238 -> closed
# 10.10.1.19:239 -> closed
# 10.10.1.19:240 -> closed
# 10.10.1.19:241 -> closed
# 10.10.1.19:242 -> closed
# 10.10.1.19:243 -> closed
# 10.10.1.19:244 -> closed
# 10.10.1.19:245 -> closed
# 10.10.1.19:246 -> closed
# 10.10.1.19:247 -> closed
# 10.10.1.19:248 -> closed
# 10.10.1.19:249 -> closed
# 10.10.1.19:250 -> closed
# 10.10.1.19:251 -> closed
# 10.10.1.19:252 -> closed
# 10.10.1.19:253 -> closed
# 10.10.1.19:254 -> closed
# 10.10.1.19:255 -> closed
# 10.10.1.19:256 -> closed
# 10.10.1.19:257 -> closed
# 10.10.1.19:258 -> closed
# 10.10.1.19:259 -> closed
# 10.10.1.19:260 -> closed
# 10.10.1.19:261 -> closed
# 10.10.1.19:262 -> closed
# 10.10.1.19:263 -> closed
# 10.10.1.19:264 -> closed
# 10.10.1.19:265 -> closed
# 10.10.1.19:266 -> closed
# 10.10.1.19:267 -> closed
# 10.10.1.19:268 -> closed
# 10.10.1.19:269 -> closed
# 10.10.1.19:270 -> closed
# 10.10.1.19:271 -> closed
# 10.10.1.19:272 -> closed
# 10.10.1.19:273 -> closed
# 10.10.1.19:274 -> closed
# 10.10.1.19:275 -> closed
# 10.10.1.19:276 -> closed
# 10.10.1.19:277 -> closed
# 10.10.1.19:278 -> closed
# 10.10.1.19:279 -> closed
# 10.10.1.19:280 -> closed
# 10.10.1.19:281 -> closed
# 10.10.1.19:282 -> closed
# 10.10.1.19:283 -> closed
# 10.10.1.19:284 -> closed
# 10.10.1.19:285 -> closed
# 10.10.1.19:286 -> closed
# 10.10.1.19:287 -> closed
# 10.10.1.19:288 -> closed
# 10.10.1.19:289 -> closed
# 10.10.1.19:290 -> closed
# 10.10.1.19:291 -> closed
# 10.10.1.19:292 -> closed
# 10.10.1.19:293 -> closed
# 10.10.1.19:294 -> closed
# 10.10.1.19:295 -> closed
# 10.10.1.19:296 -> closed
# 10.10.1.19:297 -> closed
# 10.10.1.19:298 -> closed
# 10.10.1.19:299 -> closed
# 10.10.1.19:300 -> closed
# 10.10.1.19:301 -> closed
# 10.10.1.19:302 -> closed
# 10.10.1.19:303 -> closed
# 10.10.1.19:304 -> closed
# 10.10.1.19:305 -> closed
# 10.10.1.19:306 -> closed
# 10.10.1.19:307 -> closed
# 10.10.1.19:308 -> closed
# 10.10.1.19:309 -> closed
# 10.10.1.19:310 -> closed
# 10.10.1.19:311 -> closed
# 10.10.1.19:312 -> closed
# 10.10.1.19:313 -> closed
# 10.10.1.19:314 -> closed
# 10.10.1.19:315 -> closed
# 10.10.1.19:316 -> closed
# 10.10.1.19:317 -> closed
# 10.10.1.19:318 -> closed
# 10.10.1.19:319 -> closed
# 10.10.1.19:320 -> closed
# 10.10.1.19:321 -> closed
# 10.10.1.19:322 -> closed
# 10.10.1.19:323 -> closed
# 10.10.1.19:324 -> closed
# 10.10.1.19:325 -> closed
# 10.10.1.19:326 -> closed
# 10.10.1.19:327 -> closed
# 10.10.1.19:328 -> closed
# 10.10.1.19:329 -> closed
# 10.10.1.19:330 -> closed
# 10.10.1.19:331 -> closed
# 10.10.1.19:332 -> closed
# 10.10.1.19:333 -> closed
# 10.10.1.19:334 -> closed
# 10.10.1.19:335 -> closed
# 10.10.1.19:336 -> closed
# 10.10.1.19:337 -> closed
# 10.10.1.19:338 -> closed
# 10.10.1.19:339 -> closed
# 10.10.1.19:340 -> closed
# 10.10.1.19:341 -> closed
# 10.10.1.19:342 -> closed
# 10.10.1.19:343 -> closed
# 10.10.1.19:344 -> closed
# 10.10.1.19:345 -> closed
# 10.10.1.19:346 -> closed
# 10.10.1.19:347 -> closed
# 10.10.1.19:348 -> closed
# 10.10.1.19:349 -> closed
# 10.10.1.19:350 -> closed
# 10.10.1.19:351 -> closed
# 10.10.1.19:352 -> closed
# 10.10.1.19:353 -> closed
# 10.10.1.19:354 -> closed
# 10.10.1.19:355 -> closed
# 10.10.1.19:356 -> closed
# 10.10.1.19:357 -> closed
# 10.10.1.19:358 -> closed
# 10.10.1.19:359 -> closed
# 10.10.1.19:360 -> closed
# 10.10.1.19:361 -> closed
# 10.10.1.19:362 -> closed
# 10.10.1.19:363 -> closed
# 10.10.1.19:364 -> closed
# 10.10.1.19:365 -> closed
# 10.10.1.19:366 -> closed
# 10.10.1.19:367 -> closed
# 10.10.1.19:368 -> closed
# 10.10.1.19:369 -> closed
# 10.10.1.19:370 -> closed
# 10.10.1.19:371 -> closed
# 10.10.1.19:372 -> closed
# 10.10.1.19:373 -> closed
# 10.10.1.19:374 -> closed
# 10.10.1.19:375 -> closed
# 10.10.1.19:376 -> closed
# 10.10.1.19:377 -> closed
# 10.10.1.19:378 -> closed
# 10.10.1.19:379 -> closed
# 10.10.1.19:380 -> closed
# 10.10.1.19:381 -> closed
# 10.10.1.19:382 -> closed
# 10.10.1.19:383 -> closed
# 10.10.1.19:384 -> closed
# 10.10.1.19:385 -> closed
# 10.10.1.19:386 -> closed
# 10.10.1.19:387 -> closed
# 10.10.1.19:388 -> closed
# 10.10.1.19:389 -> closed
# 10.10.1.19:390 -> closed
# 10.10.1.19:391 -> closed
# 10.10.1.19:392 -> closed
# 10.10.1.19:393 -> closed
# 10.10.1.19:394 -> closed
# 10.10.1.19:395 -> closed
# 10.10.1.19:396 -> closed
# 10.10.1.19:397 -> closed
# 10.10.1.19:398 -> closed
# 10.10.1.19:399 -> closed
# 10.10.1.19:400 -> closed
# 10.10.1.19:401 -> closed
# 10.10.1.19:402 -> closed
# 10.10.1.19:403 -> closed
# 10.10.1.19:404 -> closed
# 10.10.1.19:405 -> closed
# 10.10.1.19:406 -> closed
# 10.10.1.19:407 -> closed
# 10.10.1.19:408 -> closed
# 10.10.1.19:409 -> closed
# 10.10.1.19:410 -> closed
# 10.10.1.19:411 -> closed
# 10.10.1.19:412 -> closed
# 10.10.1.19:413 -> closed
# 10.10.1.19:414 -> closed
# 10.10.1.19:415 -> closed
# 10.10.1.19:416 -> closed
# 10.10.1.19:417 -> closed
# 10.10.1.19:418 -> closed
# 10.10.1.19:419 -> closed
# 10.10.1.19:420 -> closed
# 10.10.1.19:421 -> closed
# 10.10.1.19:422 -> closed
# 10.10.1.19:423 -> closed
# 10.10.1.19:424 -> closed
# 10.10.1.19:425 -> closed
# 10.10.1.19:426 -> closed
# 10.10.1.19:427 -> closed
# 10.10.1.19:428 -> closed
# 10.10.1.19:429 -> closed
# 10.10.1.19:430 -> closed
# 10.10.1.19:431 -> closed
# 10.10.1.19:432 -> closed
# 10.10.1.19:433 -> closed
# 10.10.1.19:434 -> closed
# 10.10.1.19:435 -> closed
# 10.10.1.19:436 -> closed
# 10.10.1.19:437 -> closed
# 10.10.1.19:438 -> closed
# 10.10.1.19:439 -> closed
# 10.10.1.19:440 -> closed
# 10.10.1.19:441 -> closed
# 10.10.1.19:442 -> closed
# 10.10.1.19:443 -> closed
# 10.10.1.19:444 -> closed
# 10.10.1.19:445 -> closed
# 10.10.1.19:446 -> closed
# 10.10.1.19:447 -> closed
# 10.10.1.19:448 -> closed
# 10.10.1.19:449 -> closed
# 10.10.1.19:450 -> closed
# 10.10.1.19:451 -> closed
# 10.10.1.19:452 -> closed
# 10.10.1.19:453 -> closed
# 10.10.1.19:454 -> closed
# 10.10.1.19:455 -> closed
# 10.10.1.19:456 -> closed
# 10.10.1.19:457 -> closed
# 10.10.1.19:458 -> closed
# 10.10.1.19:459 -> closed
# 10.10.1.19:460 -> closed
# 10.10.1.19:461 -> closed
# 10.10.1.19:462 -> closed
# 10.10.1.19:463 -> closed
# 10.10.1.19:464 -> closed
# 10.10.1.19:465 -> closed
# 10.10.1.19:466 -> closed
# 10.10.1.19:467 -> closed
# 10.10.1.19:468 -> closed
# 10.10.1.19:469 -> closed
# 10.10.1.19:470 -> closed
# 10.10.1.19:471 -> closed
# 10.10.1.19:472 -> closed
# 10.10.1.19:473 -> closed
# 10.10.1.19:474 -> closed
# 10.10.1.19:475 -> closed
# 10.10.1.19:476 -> closed
# 10.10.1.19:477 -> closed
# 10.10.1.19:478 -> closed
# 10.10.1.19:479 -> closed
# 10.10.1.19:480 -> closed
# 10.10.1.19:481 -> closed
# 10.10.1.19:482 -> closed
# 10.10.1.19:483 -> closed
# 10.10.1.19:484 -> closed
# 10.10.1.19:485 -> closed
# 10.10.1.19:486 -> closed
# 10.10.1.19:487 -> closed
# 10.10.1.19:488 -> closed
# 10.10.1.19:489 -> closed
# 10.10.1.19:490 -> closed
# 10.10.1.19:491 -> closed
# 10.10.1.19:492 -> closed
# 10.10.1.19:493 -> closed
# 10.10.1.19:494 -> closed
# 10.10.1.19:495 -> closed
# 10.10.1.19:496 -> closed
# 10.10.1.19:497 -> closed
# 10.10.1.19:498 -> closed
# 10.10.1.19:499 -> closed
# 10.10.1.19:500 -> closed
# 10.10.1.19:501 -> closed
# 10.10.1.19:502 -> closed
# 10.10.1.19:503 -> closed
# 10.10.1.19:504 -> closed
# 10.10.1.19:505 -> closed
# 10.10.1.19:506 -> closed
# 10.10.1.19:507 -> closed
# 10.10.1.19:508 -> closed
# 10.10.1.19:509 -> closed
# 10.10.1.19:510 -> closed
# 10.10.1.19:511 -> closed
# 10.10.1.19:512 -> closed
# 10.10.1.19:513 -> closed
# 10.10.1.19:514 -> closed
# 10.10.1.19:515 -> closed
# 10.10.1.19:516 -> closed
# 10.10.1.19:517 -> closed
# 10.10.1.19:518 -> closed
# 10.10.1.19:519 -> closed
# 10.10.1.19:520 -> closed
# 10.10.1.19:521 -> closed
# 10.10.1.19:522 -> closed
# 10.10.1.19:523 -> closed
# 10.10.1.19:524 -> closed
# 10.10.1.19:525 -> closed
# 10.10.1.19:526 -> closed
# 10.10.1.19:527 -> closed
# 10.10.1.19:528 -> closed
# 10.10.1.19:529 -> closed
# 10.10.1.19:530 -> closed
# 10.10.1.19:531 -> closed
# 10.10.1.19:532 -> closed
# 10.10.1.19:533 -> closed
# 10.10.1.19:534 -> closed
# 10.10.1.19:535 -> closed
# 10.10.1.19:536 -> closed
# 10.10.1.19:537 -> closed
# 10.10.1.19:538 -> closed
# 10.10.1.19:539 -> closed
# 10.10.1.19:540 -> closed
# 10.10.1.19:541 -> closed
# 10.10.1.19:542 -> closed
# 10.10.1.19:543 -> closed
# 10.10.1.19:544 -> closed
# 10.10.1.19:545 -> closed
# 10.10.1.19:546 -> closed
# 10.10.1.19:547 -> closed
# 10.10.1.19:548 -> closed
# 10.10.1.19:549 -> closed
# 10.10.1.19:550 -> closed
# 10.10.1.19:551 -> closed
# 10.10.1.19:552 -> closed
# 10.10.1.19:553 -> closed
# 10.10.1.19:554 -> closed
# 10.10.1.19:555 -> closed
# 10.10.1.19:556 -> closed
# 10.10.1.19:557 -> closed
# 10.10.1.19:558 -> closed
# 10.10.1.19:559 -> closed
# 10.10.1.19:560 -> closed
# 10.10.1.19:561 -> closed
# 10.10.1.19:562 -> closed
# 10.10.1.19:563 -> closed
# 10.10.1.19:564 -> closed
# 10.10.1.19:565 -> closed
# 10.10.1.19:566 -> closed
# 10.10.1.19:567 -> closed
# 10.10.1.19:568 -> closed
# 10.10.1.19:569 -> closed
# 10.10.1.19:570 -> closed
# 10.10.1.19:571 -> closed
# 10.10.1.19:572 -> closed
# 10.10.1.19:573 -> closed
# 10.10.1.19:574 -> closed
# 10.10.1.19:575 -> closed
# 10.10.1.19:576 -> closed
# 10.10.1.19:577 -> closed
# 10.10.1.19:578 -> closed
# 10.10.1.19:579 -> closed
# 10.10.1.19:580 -> closed
# 10.10.1.19:581 -> closed
# 10.10.1.19:582 -> closed
# 10.10.1.19:583 -> closed
# 10.10.1.19:584 -> closed
# 10.10.1.19:585 -> closed
# 10.10.1.19:586 -> closed
# 10.10.1.19:587 -> closed
# 10.10.1.19:588 -> closed
# 10.10.1.19:589 -> closed
# 10.10.1.19:590 -> closed
# 10.10.1.19:591 -> closed
# 10.10.1.19:592 -> closed
# 10.10.1.19:593 -> closed
# 10.10.1.19:594 -> closed
# 10.10.1.19:595 -> closed
# 10.10.1.19:596 -> closed
# 10.10.1.19:597 -> closed
# 10.10.1.19:598 -> closed
# 10.10.1.19:599 -> closed
# 10.10.1.19:600 -> closed
# 10.10.1.19:601 -> closed
# 10.10.1.19:602 -> closed
# 10.10.1.19:603 -> closed
# 10.10.1.19:604 -> closed
# 10.10.1.19:605 -> closed
# 10.10.1.19:606 -> closed
# 10.10.1.19:607 -> closed
# 10.10.1.19:608 -> closed
# 10.10.1.19:609 -> closed
# 10.10.1.19:610 -> closed
# 10.10.1.19:611 -> closed
# 10.10.1.19:612 -> closed
# 10.10.1.19:613 -> closed
# 10.10.1.19:614 -> closed
# 10.10.1.19:615 -> closed
# 10.10.1.19:616 -> closed
# 10.10.1.19:617 -> closed
# 10.10.1.19:618 -> closed
# 10.10.1.19:619 -> closed
# 10.10.1.19:620 -> closed
# 10.10.1.19:621 -> closed
# 10.10.1.19:622 -> closed
# 10.10.1.19:623 -> closed
# 10.10.1.19:624 -> closed
# 10.10.1.19:625 -> closed
# 10.10.1.19:626 -> closed
# 10.10.1.19:627 -> closed
# 10.10.1.19:628 -> closed
# 10.10.1.19:629 -> closed
# 10.10.1.19:630 -> closed
# 10.10.1.19:631 -> closed
# 10.10.1.19:632 -> closed
# 10.10.1.19:633 -> closed
# 10.10.1.19:634 -> closed
# 10.10.1.19:635 -> closed
# 10.10.1.19:636 -> closed
# 10.10.1.19:637 -> closed
# 10.10.1.19:638 -> closed
# 10.10.1.19:639 -> closed
# 10.10.1.19:640 -> closed
# 10.10.1.19:641 -> closed
# 10.10.1.19:642 -> closed
# 10.10.1.19:643 -> closed
# 10.10.1.19:644 -> closed
# 10.10.1.19:645 -> closed
# 10.10.1.19:646 -> closed
# 10.10.1.19:647 -> closed
# 10.10.1.19:648 -> closed
# 10.10.1.19:649 -> closed
# 10.10.1.19:650 -> closed
# 10.10.1.19:651 -> closed
# 10.10.1.19:652 -> closed
# 10.10.1.19:653 -> closed
# 10.10.1.19:654 -> closed
# 10.10.1.19:655 -> closed
# 10.10.1.19:656 -> closed
# 10.10.1.19:657 -> closed
# 10.10.1.19:658 -> closed
# 10.10.1.19:659 -> closed
# 10.10.1.19:660 -> closed
# 10.10.1.19:661 -> closed
# 10.10.1.19:662 -> closed
# 10.10.1.19:663 -> closed
# 10.10.1.19:664 -> closed
# 10.10.1.19:665 -> closed
# 10.10.1.19:666 -> closed
# 10.10.1.19:667 -> closed
# 10.10.1.19:668 -> closed
# 10.10.1.19:669 -> closed
# 10.10.1.19:670 -> closed
# 10.10.1.19:671 -> closed
# 10.10.1.19:672 -> closed
# 10.10.1.19:673 -> closed
# 10.10.1.19:674 -> closed
# 10.10.1.19:675 -> closed
# 10.10.1.19:676 -> closed
# 10.10.1.19:677 -> closed
# 10.10.1.19:678 -> closed
# 10.10.1.19:679 -> closed
# 10.10.1.19:680 -> closed
# 10.10.1.19:681 -> closed
# 10.10.1.19:682 -> closed
# 10.10.1.19:683 -> closed
# 10.10.1.19:684 -> closed
# 10.10.1.19:685 -> closed
# 10.10.1.19:686 -> closed
# 10.10.1.19:687 -> closed
# 10.10.1.19:688 -> closed
# 10.10.1.19:689 -> closed
# 10.10.1.19:690 -> closed
# 10.10.1.19:691 -> closed
# 10.10.1.19:692 -> closed
# 10.10.1.19:693 -> closed
# 10.10.1.19:694 -> closed
# 10.10.1.19:695 -> closed
# 10.10.1.19:696 -> closed
# 10.10.1.19:697 -> closed
# 10.10.1.19:698 -> closed
# 10.10.1.19:699 -> closed
# 10.10.1.19:700 -> closed
# 10.10.1.19:701 -> closed
# 10.10.1.19:702 -> closed
# 10.10.1.19:703 -> closed
# 10.10.1.19:704 -> closed
# 10.10.1.19:705 -> closed
# 10.10.1.19:706 -> closed
# 10.10.1.19:707 -> closed
# 10.10.1.19:708 -> closed
# 10.10.1.19:709 -> closed
# 10.10.1.19:710 -> closed
# 10.10.1.19:711 -> closed
# 10.10.1.19:712 -> closed
# 10.10.1.19:713 -> closed
# 10.10.1.19:714 -> closed
# 10.10.1.19:715 -> closed
# 10.10.1.19:716 -> closed
# 10.10.1.19:717 -> closed
# 10.10.1.19:718 -> closed
# 10.10.1.19:719 -> closed
# 10.10.1.19:720 -> closed
# 10.10.1.19:721 -> closed
# 10.10.1.19:722 -> closed
# 10.10.1.19:723 -> closed
# 10.10.1.19:724 -> closed
# 10.10.1.19:725 -> closed
# 10.10.1.19:726 -> closed
# 10.10.1.19:727 -> closed
# 10.10.1.19:728 -> closed
# 10.10.1.19:729 -> closed
# 10.10.1.19:730 -> closed
# 10.10.1.19:731 -> closed
# 10.10.1.19:732 -> closed
# 10.10.1.19:733 -> closed
# 10.10.1.19:734 -> closed
# 10.10.1.19:735 -> closed
# 10.10.1.19:736 -> closed
# 10.10.1.19:737 -> closed
# 10.10.1.19:738 -> closed
# 10.10.1.19:739 -> closed
# 10.10.1.19:740 -> closed
# 10.10.1.19:741 -> closed
# 10.10.1.19:742 -> closed
# 10.10.1.19:743 -> closed
# 10.10.1.19:744 -> closed
# 10.10.1.19:745 -> closed
# 10.10.1.19:746 -> closed
# 10.10.1.19:747 -> closed
# 10.10.1.19:748 -> closed
# 10.10.1.19:749 -> closed
# 10.10.1.19:750 -> closed
# 10.10.1.19:751 -> closed
# 10.10.1.19:752 -> closed
# 10.10.1.19:753 -> closed
# 10.10.1.19:754 -> closed
# 10.10.1.19:755 -> closed
# 10.10.1.19:756 -> closed
# 10.10.1.19:757 -> closed
# 10.10.1.19:758 -> closed
# 10.10.1.19:759 -> closed
# 10.10.1.19:760 -> closed
# 10.10.1.19:761 -> closed
# 10.10.1.19:762 -> closed
# 10.10.1.19:763 -> closed
# 10.10.1.19:764 -> closed
# 10.10.1.19:765 -> closed
# 10.10.1.19:766 -> closed
# 10.10.1.19:767 -> closed
# 10.10.1.19:768 -> closed
# 10.10.1.19:769 -> closed
# 10.10.1.19:770 -> closed
# 10.10.1.19:771 -> closed
# 10.10.1.19:772 -> closed
# 10.10.1.19:773 -> closed
# 10.10.1.19:774 -> closed
# 10.10.1.19:775 -> closed
# 10.10.1.19:776 -> closed
# 10.10.1.19:777 -> closed
# 10.10.1.19:778 -> closed
# 10.10.1.19:779 -> closed
# 10.10.1.19:780 -> closed
# 10.10.1.19:781 -> closed
# 10.10.1.19:782 -> closed
# 10.10.1.19:783 -> closed
# 10.10.1.19:784 -> closed
# 10.10.1.19:785 -> closed
# 10.10.1.19:786 -> closed
# 10.10.1.19:787 -> closed
# 10.10.1.19:788 -> closed
# 10.10.1.19:789 -> closed
# 10.10.1.19:790 -> closed
# 10.10.1.19:791 -> closed
# 10.10.1.19:792 -> closed
# 10.10.1.19:793 -> closed
# 10.10.1.19:794 -> closed
# 10.10.1.19:795 -> closed
# 10.10.1.19:796 -> closed
# 10.10.1.19:797 -> closed
# 10.10.1.19:798 -> closed
# 10.10.1.19:799 -> closed
# 10.10.1.19:800 -> closed
# 10.10.1.19:801 -> closed
# 10.10.1.19:802 -> closed
# 10.10.1.19:803 -> closed
# 10.10.1.19:804 -> closed
# 10.10.1.19:805 -> closed
# 10.10.1.19:806 -> closed
# 10.10.1.19:807 -> closed
# 10.10.1.19:808 -> closed
# 10.10.1.19:809 -> closed
# 10.10.1.19:810 -> closed
# 10.10.1.19:811 -> closed
# 10.10.1.19:812 -> closed
# 10.10.1.19:813 -> closed
# 10.10.1.19:814 -> closed
# 10.10.1.19:815 -> closed
# 10.10.1.19:816 -> closed
# 10.10.1.19:817 -> closed
# 10.10.1.19:818 -> closed
# 10.10.1.19:819 -> closed
# 10.10.1.19:820 -> closed
# 10.10.1.19:821 -> closed
# 10.10.1.19:822 -> closed
# 10.10.1.19:823 -> closed
# 10.10.1.19:824 -> closed
# 10.10.1.19:825 -> closed
# 10.10.1.19:826 -> closed
# 10.10.1.19:827 -> closed
# 10.10.1.19:828 -> closed
# 10.10.1.19:829 -> closed
# 10.10.1.19:830 -> closed
# 10.10.1.19:831 -> closed
# 10.10.1.19:832 -> closed
# 10.10.1.19:833 -> closed
# 10.10.1.19:834 -> closed
# 10.10.1.19:835 -> closed
# 10.10.1.19:836 -> closed
# 10.10.1.19:837 -> closed
# 10.10.1.19:838 -> closed
# 10.10.1.19:839 -> closed
# 10.10.1.19:840 -> closed
# 10.10.1.19:841 -> closed
# 10.10.1.19:842 -> closed
# 10.10.1.19:843 -> closed
# 10.10.1.19:844 -> closed
# 10.10.1.19:845 -> closed
# 10.10.1.19:846 -> closed
# 10.10.1.19:847 -> closed
# 10.10.1.19:848 -> closed
# 10.10.1.19:849 -> closed
# 10.10.1.19:850 -> closed
# 10.10.1.19:851 -> closed
# 10.10.1.19:852 -> closed
# 10.10.1.19:853 -> closed
# 10.10.1.19:854 -> closed
# 10.10.1.19:855 -> closed
# 10.10.1.19:856 -> closed
# 10.10.1.19:857 -> closed
# 10.10.1.19:858 -> closed
# 10.10.1.19:859 -> closed
# 10.10.1.19:860 -> closed
# 10.10.1.19:861 -> closed
# 10.10.1.19:862 -> closed
# 10.10.1.19:863 -> closed
# 10.10.1.19:864 -> closed
# 10.10.1.19:865 -> closed
# 10.10.1.19:866 -> closed
# 10.10.1.19:867 -> closed
# 10.10.1.19:868 -> closed
# 10.10.1.19:869 -> closed
# 10.10.1.19:870 -> closed
# 10.10.1.19:871 -> closed
# 10.10.1.19:872 -> closed
# 10.10.1.19:873 -> closed
# 10.10.1.19:874 -> closed
# 10.10.1.19:875 -> closed
# 10.10.1.19:876 -> closed
# 10.10.1.19:877 -> closed
# 10.10.1.19:878 -> closed
# 10.10.1.19:879 -> closed
# 10.10.1.19:880 -> closed
# 10.10.1.19:881 -> closed
# 10.10.1.19:882 -> closed
# 10.10.1.19:883 -> closed
# 10.10.1.19:884 -> closed
# 10.10.1.19:885 -> closed
# 10.10.1.19:886 -> closed
# 10.10.1.19:887 -> closed
# 10.10.1.19:888 -> closed
# 10.10.1.19:889 -> closed
# 10.10.1.19:890 -> closed
# 10.10.1.19:891 -> closed
# 10.10.1.19:892 -> closed
# 10.10.1.19:893 -> closed
# 10.10.1.19:894 -> closed
# 10.10.1.19:895 -> closed
# 10.10.1.19:896 -> closed
# 10.10.1.19:897 -> closed
# 10.10.1.19:898 -> closed
# 10.10.1.19:899 -> closed
# 10.10.1.19:900 -> closed
# 10.10.1.19:901 -> closed
# 10.10.1.19:902 -> closed
# 10.10.1.19:903 -> closed
# 10.10.1.19:904 -> closed
# 10.10.1.19:905 -> closed
# 10.10.1.19:906 -> closed
# 10.10.1.19:907 -> closed
# 10.10.1.19:908 -> closed
# 10.10.1.19:909 -> closed
# 10.10.1.19:910 -> closed
# 10.10.1.19:911 -> closed
# 10.10.1.19:912 -> closed
# 10.10.1.19:913 -> closed
# 10.10.1.19:914 -> closed
# 10.10.1.19:915 -> closed
# 10.10.1.19:916 -> closed
# 10.10.1.19:917 -> closed
# 10.10.1.19:918 -> closed
# 10.10.1.19:919 -> closed
# 10.10.1.19:920 -> closed
# 10.10.1.19:921 -> closed
# 10.10.1.19:922 -> closed
# 10.10.1.19:923 -> closed
# 10.10.1.19:924 -> closed
# 10.10.1.19:925 -> closed
# 10.10.1.19:926 -> closed
# 10.10.1.19:927 -> closed
# 10.10.1.19:928 -> closed
# 10.10.1.19:929 -> closed
# 10.10.1.19:930 -> closed
# 10.10.1.19:931 -> closed
# 10.10.1.19:932 -> closed
# 10.10.1.19:933 -> closed
# 10.10.1.19:934 -> closed
# 10.10.1.19:935 -> closed
# 10.10.1.19:936 -> closed
# 10.10.1.19:937 -> closed
# 10.10.1.19:938 -> closed
# 10.10.1.19:939 -> closed
# 10.10.1.19:940 -> closed
# 10.10.1.19:941 -> closed
# 10.10.1.19:942 -> closed
# 10.10.1.19:943 -> closed
# 10.10.1.19:944 -> closed
# 10.10.1.19:945 -> closed
# 10.10.1.19:946 -> closed
# 10.10.1.19:947 -> closed
# 10.10.1.19:948 -> closed
# 10.10.1.19:949 -> closed
# 10.10.1.19:950 -> closed
# 10.10.1.19:951 -> closed
# 10.10.1.19:952 -> closed
# 10.10.1.19:953 -> closed
# 10.10.1.19:954 -> closed
# 10.10.1.19:955 -> closed
# 10.10.1.19:956 -> closed
# 10.10.1.19:957 -> closed
# 10.10.1.19:958 -> closed
# 10.10.1.19:959 -> closed
# 10.10.1.19:960 -> closed
# 10.10.1.19:961 -> closed
# 10.10.1.19:962 -> closed
# 10.10.1.19:963 -> closed
# 10.10.1.19:964 -> closed
# 10.10.1.19:965 -> closed
# 10.10.1.19:966 -> closed
# 10.10.1.19:967 -> closed
# 10.10.1.19:968 -> closed
# 10.10.1.19:969 -> closed
# 10.10.1.19:970 -> closed
# 10.10.1.19:971 -> closed
# 10.10.1.19:972 -> closed
# 10.10.1.19:973 -> closed
# 10.10.1.19:974 -> closed
# 10.10.1.19:975 -> closed
# 10.10.1.19:976 -> closed
# 10.10.1.19:977 -> closed
# 10.10.1.19:978 -> closed
# 10.10.1.19:979 -> closed
# 10.10.1.19:980 -> closed
# 10.10.1.19:981 -> closed
# 10.10.1.19:982 -> closed
# 10.10.1.19:983 -> closed
# 10.10.1.19:984 -> closed
# 10.10.1.19:985 -> closed
# 10.10.1.19:986 -> closed
# 10.10.1.19:987 -> closed
# 10.10.1.19:988 -> closed
# 10.10.1.19:989 -> closed
# 10.10.1.19:990 -> closed
# 10.10.1.19:991 -> closed
# 10.10.1.19:992 -> closed
# 10.10.1.19:993 -> closed
# 10.10.1.19:994 -> closed
# 10.10.1.19:995 -> closed
# 10.10.1.19:996 -> closed
# 10.10.1.19:997 -> closed
# 10.10.1.19:998 -> closed
# 10.10.1.19:999 -> closed
# 10.10.1.19:1000 -> closed
# 10.10.1.19:1001 -> closed
# 10.10.1.19:1002 -> closed
# 10.10.1.19:1003 -> closed
# 10.10.1.19:1004 -> closed
# 10.10.1.19:1005 -> closed
# 10.10.1.19:1006 -> closed
# 10.10.1.19:1007 -> closed
# 10.10.1.19:1008 -> closed
# 10.10.1.19:1009 -> closed
# 10.10.1.19:1010 -> closed
# 10.10.1.19:1011 -> closed
# 10.10.1.19:1012 -> closed
# 10.10.1.19:1013 -> closed
# 10.10.1.19:1014 -> closed
# 10.10.1.19:1015 -> closed
# 10.10.1.19:1016 -> closed
# 10.10.1.19:1017 -> closed
# 10.10.1.19:1018 -> closed
# 10.10.1.19:1019 -> closed
# 10.10.1.19:1020 -> closed
# 10.10.1.19:1021 -> closed
# 10.10.1.19:1022 -> closed
# 10.10.1.19:1023 -> closed
# 10.10.1.19:1024 -> closed
# 10.10.1.19:1025 -> closed
# 10.10.1.19:1026 -> closed
# 10.10.1.19:1027 -> closed
# 10.10.1.19:1028 -> closed
# 10.10.1.19:1029 -> closed
# 10.10.1.19:1030 -> closed
# 10.10.1.19:1031 -> closed
# 10.10.1.19:1032 -> closed
# 10.10.1.19:1033 -> closed
# 10.10.1.19:1034 -> closed
# 10.10.1.19:1035 -> closed
# 10.10.1.19:1036 -> closed
# 10.10.1.19:1037 -> closed
# 10.10.1.19:1038 -> closed
# 10.10.1.19:1039 -> closed
# 10.10.1.19:1040 -> closed
# 10.10.1.19:1041 -> closed
# 10.10.1.19:1042 -> closed
# 10.10.1.19:1043 -> closed
# 10.10.1.19:1044 -> closed
# 10.10.1.19:1045 -> closed
# 10.10.1.19:1046 -> closed
# 10.10.1.19:1047 -> closed
# 10.10.1.19:1048 -> closed
# 10.10.1.19:1049 -> closed
# 10.10.1.19:1050 -> closed
# 10.10.1.19:1051 -> closed
# 10.10.1.19:1052 -> closed
# 10.10.1.19:1053 -> closed
# 10.10.1.19:1054 -> closed
# 10.10.1.19:1055 -> closed
# 10.10.1.19:1056 -> closed
# 10.10.1.19:1057 -> closed
# 10.10.1.19:1058 -> closed
# 10.10.1.19:1059 -> closed
# 10.10.1.19:1060 -> closed
# 10.10.1.19:1061 -> closed
# 10.10.1.19:1062 -> closed
# 10.10.1.19:1063 -> closed
# 10.10.1.19:1064 -> closed
# 10.10.1.19:1065 -> closed
# 10.10.1.19:1066 -> closed
# 10.10.1.19:1067 -> closed
# 10.10.1.19:1068 -> closed
# 10.10.1.19:1069 -> closed
# 10.10.1.19:1070 -> closed
# 10.10.1.19:1071 -> closed
# 10.10.1.19:1072 -> closed
# 10.10.1.19:1073 -> closed
# 10.10.1.19:1074 -> closed
# 10.10.1.19:1075 -> closed
# 10.10.1.19:1076 -> closed
# 10.10.1.19:1077 -> closed
# 10.10.1.19:1078 -> closed
# 10.10.1.19:1079 -> closed
# 10.10.1.19:1080 -> closed
# 10.10.1.19:1081 -> closed
# 10.10.1.19:1082 -> closed
# 10.10.1.19:1083 -> closed
# 10.10.1.19:1084 -> closed
# 10.10.1.19:1085 -> closed
# 10.10.1.19:1086 -> closed
# 10.10.1.19:1087 -> closed
# 10.10.1.19:1088 -> closed
# 10.10.1.19:1089 -> closed
# 10.10.1.19:1090 -> closed
# 10.10.1.19:1091 -> closed
# 10.10.1.19:1092 -> closed
# 10.10.1.19:1093 -> closed
# 10.10.1.19:1094 -> closed
# 10.10.1.19:1095 -> closed
# 10.10.1.19:1096 -> closed
# 10.10.1.19:1097 -> closed
# 10.10.1.19:1098 -> closed
# 10.10.1.19:1099 -> closed
# 10.10.1.19:1100 -> closed
# 10.10.1.19:1101 -> closed
# 10.10.1.19:1102 -> closed
# 10.10.1.19:1103 -> closed
# 10.10.1.19:1104 -> closed
# 10.10.1.19:1105 -> closed
# 10.10.1.19:1106 -> closed
# 10.10.1.19:1107 -> closed
# 10.10.1.19:1108 -> closed
# 10.10.1.19:1109 -> closed
# 10.10.1.19:1110 -> closed
# 10.10.1.19:1111 -> closed
# 10.10.1.19:1112 -> closed
# 10.10.1.19:1113 -> closed
# 10.10.1.19:1114 -> closed
# 10.10.1.19:1115 -> closed
# 10.10.1.19:1116 -> closed
# 10.10.1.19:1117 -> closed
# 10.10.1.19:1118 -> closed
# 10.10.1.19:1119 -> closed
# 10.10.1.19:1120 -> closed
# 10.10.1.19:1121 -> closed
# 10.10.1.19:1122 -> closed
# 10.10.1.19:1123 -> closed
# 10.10.1.19:1124 -> closed
# 10.10.1.19:1125 -> closed
# 10.10.1.19:1126 -> closed
# 10.10.1.19:1127 -> closed
# 10.10.1.19:1128 -> closed
# 10.10.1.19:1129 -> closed
# 10.10.1.19:1130 -> closed
# 10.10.1.19:1131 -> closed
# 10.10.1.19:1132 -> closed
# 10.10.1.19:1133 -> closed
# 10.10.1.19:1134 -> closed
# 10.10.1.19:1135 -> closed
# 10.10.1.19:1136 -> closed
# 10.10.1.19:1137 -> closed
# 10.10.1.19:1138 -> closed
# 10.10.1.19:1139 -> closed
# 10.10.1.19:1140 -> closed
# 10.10.1.19:1141 -> closed
# 10.10.1.19:1142 -> closed
# 10.10.1.19:1143 -> closed
# 10.10.1.19:1144 -> closed
# 10.10.1.19:1145 -> closed
# 10.10.1.19:1146 -> closed
# 10.10.1.19:1147 -> closed
# 10.10.1.19:1148 -> closed
# 10.10.1.19:1149 -> closed
# 10.10.1.19:1150 -> closed
# 10.10.1.19:1151 -> closed
# 10.10.1.19:1152 -> closed
# 10.10.1.19:1153 -> closed
# 10.10.1.19:1154 -> closed
# 10.10.1.19:1155 -> closed
# 10.10.1.19:1156 -> closed
# 10.10.1.19:1157 -> closed
# 10.10.1.19:1158 -> closed
# 10.10.1.19:1159 -> closed
# 10.10.1.19:1160 -> closed
# 10.10.1.19:1161 -> closed
# 10.10.1.19:1162 -> closed
# 10.10.1.19:1163 -> closed
# 10.10.1.19:1164 -> closed
# 10.10.1.19:1165 -> closed
# 10.10.1.19:1166 -> closed
# 10.10.1.19:1167 -> closed
# 10.10.1.19:1168 -> closed
# 10.10.1.19:1169 -> closed
# 10.10.1.19:1170 -> closed
# 10.10.1.19:1171 -> closed
# 10.10.1.19:1172 -> closed
# 10.10.1.19:1173 -> closed
# 10.10.1.19:1174 -> closed
# 10.10.1.19:1175 -> closed
# 10.10.1.19:1176 -> closed
# 10.10.1.19:1177 -> closed
# 10.10.1.19:1178 -> closed
# 10.10.1.19:1179 -> closed
# 10.10.1.19:1180 -> closed
# 10.10.1.19:1181 -> closed
# 10.10.1.19:1182 -> closed
# 10.10.1.19:1183 -> closed
# 10.10.1.19:1184 -> closed
# 10.10.1.19:1185 -> closed
# 10.10.1.19:1186 -> closed
# 10.10.1.19:1187 -> closed
# 10.10.1.19:1188 -> closed
# 10.10.1.19:1189 -> closed
# 10.10.1.19:1190 -> closed
# 10.10.1.19:1191 -> closed
# 10.10.1.19:1192 -> closed
# 10.10.1.19:1193 -> closed
# 10.10.1.19:1194 -> closed
# 10.10.1.19:1195 -> closed
# 10.10.1.19:1196 -> closed
# 10.10.1.19:1197 -> closed
# 10.10.1.19:1198 -> closed
# 10.10.1.19:1199 -> closed
# 10.10.1.19:1200 -> closed
# 10.10.1.19:1201 -> closed
# 10.10.1.19:1202 -> closed
# 10.10.1.19:1203 -> closed
# 10.10.1.19:1204 -> closed
# 10.10.1.19:1205 -> closed
# 10.10.1.19:1206 -> closed
# 10.10.1.19:1207 -> closed
# 10.10.1.19:1208 -> closed
# 10.10.1.19:1209 -> closed
# 10.10.1.19:1210 -> closed
# 10.10.1.19:1211 -> closed
# 10.10.1.19:1212 -> closed
# 10.10.1.19:1213 -> closed
# 10.10.1.19:1214 -> closed
# 10.10.1.19:1215 -> closed
# 10.10.1.19:1216 -> closed
# 10.10.1.19:1217 -> closed
# 10.10.1.19:1218 -> closed
# 10.10.1.19:1219 -> closed
# 10.10.1.19:1220 -> closed
# 10.10.1.19:1221 -> closed
# 10.10.1.19:1222 -> closed
# 10.10.1.19:1223 -> closed
# 10.10.1.19:1224 -> closed
# 10.10.1.19:1225 -> closed
# 10.10.1.19:1226 -> closed
# 10.10.1.19:1227 -> closed
# 10.10.1.19:1228 -> closed
# 10.10.1.19:1229 -> closed
# 10.10.1.19:1230 -> closed
# 10.10.1.19:1231 -> closed
# 10.10.1.19:1232 -> closed
# 10.10.1.19:1233 -> closed
# 10.10.1.19:1234 -> closed
# 10.10.1.19:1235 -> closed
# 10.10.1.19:1236 -> closed
# 10.10.1.19:1237 -> closed
# 10.10.1.19:1238 -> closed
# 10.10.1.19:1239 -> closed
# 10.10.1.19:1240 -> closed
# 10.10.1.19:1241 -> closed
# 10.10.1.19:1242 -> closed
# 10.10.1.19:1243 -> closed
# 10.10.1.19:1244 -> closed
# 10.10.1.19:1245 -> closed
# 10.10.1.19:1246 -> closed
# 10.10.1.19:1247 -> closed
# 10.10.1.19:1248 -> closed
# 10.10.1.19:1249 -> closed
# 10.10.1.19:1250 -> closed
# 10.10.1.19:1251 -> closed
# 10.10.1.19:1252 -> closed
# 10.10.1.19:1253 -> closed
# 10.10.1.19:1254 -> closed
# 10.10.1.19:1255 -> closed
# 10.10.1.19:1256 -> closed
# 10.10.1.19:1257 -> closed
# 10.10.1.19:1258 -> closed
# 10.10.1.19:1259 -> closed
# 10.10.1.19:1260 -> closed
# 10.10.1.19:1261 -> closed
# 10.10.1.19:1262 -> closed
# 10.10.1.19:1263 -> closed
# 10.10.1.19:1264 -> closed
# 10.10.1.19:1265 -> closed
# 10.10.1.19:1266 -> closed
# 10.10.1.19:1267 -> closed
# 10.10.1.19:1268 -> closed
# 10.10.1.19:1269 -> closed
# 10.10.1.19:1270 -> closed
# 10.10.1.19:1271 -> closed
# 10.10.1.19:1272 -> closed
# 10.10.1.19:1273 -> closed
# 10.10.1.19:1274 -> closed
# 10.10.1.19:1275 -> closed
# 10.10.1.19:1276 -> closed
# 10.10.1.19:1277 -> closed
# 10.10.1.19:1278 -> closed
# 10.10.1.19:1279 -> closed
# 10.10.1.19:1280 -> closed
# 10.10.1.19:1281 -> closed
# 10.10.1.19:1282 -> closed
# 10.10.1.19:1283 -> closed
# 10.10.1.19:1284 -> closed
# 10.10.1.19:1285 -> closed
# 10.10.1.19:1286 -> closed
# 10.10.1.19:1287 -> closed
# 10.10.1.19:1288 -> closed
# 10.10.1.19:1289 -> closed
# 10.10.1.19:1290 -> closed
# 10.10.1.19:1291 -> closed
# 10.10.1.19:1292 -> closed
# 10.10.1.19:1293 -> closed
# 10.10.1.19:1294 -> closed
# 10.10.1.19:1295 -> closed
# 10.10.1.19:1296 -> closed
# 10.10.1.19:1297 -> closed
# 10.10.1.19:1298 -> closed
# 10.10.1.19:1299 -> closed
# 10.10.1.19:1300 -> closed
# 10.10.1.19:1301 -> closed
# 10.10.1.19:1302 -> closed
# 10.10.1.19:1303 -> closed
# 10.10.1.19:1304 -> closed
# 10.10.1.19:1305 -> closed
# 10.10.1.19:1306 -> closed
# 10.10.1.19:1307 -> closed
# 10.10.1.19:1308 -> closed
# 10.10.1.19:1309 -> closed
# 10.10.1.19:1310 -> closed
# 10.10.1.19:1311 -> closed
# 10.10.1.19:1312 -> closed
# 10.10.1.19:1313 -> closed
# 10.10.1.19:1314 -> closed
# 10.10.1.19:1315 -> closed
# 10.10.1.19:1316 -> closed
# 10.10.1.19:1317 -> closed
# 10.10.1.19:1318 -> closed
# 10.10.1.19:1319 -> closed
# 10.10.1.19:1320 -> closed
# 10.10.1.19:1321 -> closed
# 10.10.1.19:1322 -> closed
# 10.10.1.19:1323 -> closed
# 10.10.1.19:1324 -> closed
# 10.10.1.19:1325 -> closed
# 10.10.1.19:1326 -> closed
# 10.10.1.19:1327 -> closed
# 10.10.1.19:1328 -> closed
# 10.10.1.19:1329 -> closed
# 10.10.1.19:1330 -> closed
# 10.10.1.19:1331 -> closed
# 10.10.1.19:1332 -> closed
# 10.10.1.19:1333 -> closed
# 10.10.1.19:1334 -> closed
# 10.10.1.19:1335 -> closed
# 10.10.1.19:1336 -> closed
# 10.10.1.19:1337 -> closed
# 10.10.1.19:1338 -> closed
# 10.10.1.19:1339 -> closed
# 10.10.1.19:1340 -> closed
# 10.10.1.19:1341 -> closed
# 10.10.1.19:1342 -> closed
# 10.10.1.19:1343 -> closed
# 10.10.1.19:1344 -> closed
# 10.10.1.19:1345 -> closed
# 10.10.1.19:1346 -> closed
# 10.10.1.19:1347 -> closed
# 10.10.1.19:1348 -> closed
# 10.10.1.19:1349 -> closed
# 10.10.1.19:1350 -> closed
# 10.10.1.19:1351 -> closed
# 10.10.1.19:1352 -> closed
# 10.10.1.19:1353 -> closed
# 10.10.1.19:1354 -> closed
# 10.10.1.19:1355 -> closed
# 10.10.1.19:1356 -> closed
# 10.10.1.19:1357 -> closed
# 10.10.1.19:1358 -> closed
# 10.10.1.19:1359 -> closed
# 10.10.1.19:1360 -> closed
# 10.10.1.19:1361 -> closed
# 10.10.1.19:1362 -> closed
# 10.10.1.19:1363 -> closed
# 10.10.1.19:1364 -> closed
# 10.10.1.19:1365 -> closed
# 10.10.1.19:1366 -> closed
# 10.10.1.19:1367 -> closed
# 10.10.1.19:1368 -> closed
# 10.10.1.19:1369 -> closed
# 10.10.1.19:1370 -> closed
# 10.10.1.19:1371 -> closed
# 10.10.1.19:1372 -> closed
# 10.10.1.19:1373 -> closed
# 10.10.1.19:1374 -> closed
# 10.10.1.19:1375 -> closed
# 10.10.1.19:1376 -> closed
# 10.10.1.19:1377 -> closed
# 10.10.1.19:1378 -> closed
# 10.10.1.19:1379 -> closed
# 10.10.1.19:1380 -> closed
# 10.10.1.19:1381 -> closed
# 10.10.1.19:1382 -> closed
# 10.10.1.19:1383 -> closed
# 10.10.1.19:1384 -> closed
# 10.10.1.19:1385 -> closed
# 10.10.1.19:1386 -> closed
# 10.10.1.19:1387 -> closed
# 10.10.1.19:1388 -> closed
# 10.10.1.19:1389 -> closed
# 10.10.1.19:1390 -> closed
# 10.10.1.19:1391 -> closed
# 10.10.1.19:1392 -> closed
# 10.10.1.19:1393 -> closed
# 10.10.1.19:1394 -> closed
# 10.10.1.19:1395 -> closed
# 10.10.1.19:1396 -> closed
# 10.10.1.19:1397 -> closed
# 10.10.1.19:1398 -> closed
# 10.10.1.19:1399 -> closed
# 10.10.1.19:1400 -> closed
# 10.10.1.19:1401 -> closed
# 10.10.1.19:1402 -> closed
# 10.10.1.19:1403 -> closed
# 10.10.1.19:1404 -> closed
# 10.10.1.19:1405 -> closed
# 10.10.1.19:1406 -> closed
# 10.10.1.19:1407 -> closed
# 10.10.1.19:1408 -> closed
# 10.10.1.19:1409 -> closed
# 10.10.1.19:1410 -> closed
# 10.10.1.19:1411 -> closed
# 10.10.1.19:1412 -> closed
# 10.10.1.19:1413 -> closed
# 10.10.1.19:1414 -> closed
# 10.10.1.19:1415 -> closed
# 10.10.1.19:1416 -> closed
# 10.10.1.19:1417 -> closed
# 10.10.1.19:1418 -> closed
# 10.10.1.19:1419 -> closed
# 10.10.1.19:1420 -> closed
# 10.10.1.19:1421 -> closed
# 10.10.1.19:1422 -> closed
# 10.10.1.19:1423 -> closed
# 10.10.1.19:1424 -> closed
# 10.10.1.19:1425 -> closed
# 10.10.1.19:1426 -> closed
# 10.10.1.19:1427 -> closed
# 10.10.1.19:1428 -> closed
# 10.10.1.19:1429 -> closed
# 10.10.1.19:1430 -> closed
# 10.10.1.19:1431 -> closed
# 10.10.1.19:1432 -> closed
# 10.10.1.19:1433 -> closed
# 10.10.1.19:1434 -> closed
# 10.10.1.19:1435 -> closed
# 10.10.1.19:1436 -> closed
# 10.10.1.19:1437 -> closed
# 10.10.1.19:1438 -> closed
# 10.10.1.19:1439 -> closed
# 10.10.1.19:1440 -> closed
# 10.10.1.19:1441 -> closed
# 10.10.1.19:1442 -> closed
# 10.10.1.19:1443 -> closed
# 10.10.1.19:1444 -> closed
# 10.10.1.19:1445 -> closed
# 10.10.1.19:1446 -> closed
# 10.10.1.19:1447 -> closed
# 10.10.1.19:1448 -> closed
# 10.10.1.19:1449 -> closed
# 10.10.1.19:1450 -> closed
# 10.10.1.19:1451 -> closed
# 10.10.1.19:1452 -> closed
# 10.10.1.19:1453 -> closed
# 10.10.1.19:1454 -> closed
# 10.10.1.19:1455 -> closed
# 10.10.1.19:1456 -> closed
# 10.10.1.19:1457 -> closed
# 10.10.1.19:1458 -> closed
# 10.10.1.19:1459 -> closed
# 10.10.1.19:1460 -> closed
# 10.10.1.19:1461 -> closed
# 10.10.1.19:1462 -> closed
# 10.10.1.19:1463 -> closed
# 10.10.1.19:1464 -> closed
# 10.10.1.19:1465 -> closed
# 10.10.1.19:1466 -> closed
# 10.10.1.19:1467 -> closed
# 10.10.1.19:1468 -> closed
# 10.10.1.19:1469 -> closed
# 10.10.1.19:1470 -> closed
# 10.10.1.19:1471 -> closed
# 10.10.1.19:1472 -> closed
# 10.10.1.19:1473 -> closed
# 10.10.1.19:1474 -> closed
# 10.10.1.19:1475 -> closed
# 10.10.1.19:1476 -> closed
# 10.10.1.19:1477 -> closed
# 10.10.1.19:1478 -> closed
# 10.10.1.19:1479 -> closed
# 10.10.1.19:1480 -> closed
# 10.10.1.19:1481 -> closed
# 10.10.1.19:1482 -> closed
# 10.10.1.19:1483 -> closed
# 10.10.1.19:1484 -> closed
# 10.10.1.19:1485 -> closed
# 10.10.1.19:1486 -> closed
# 10.10.1.19:1487 -> closed
# 10.10.1.19:1488 -> closed
# 10.10.1.19:1489 -> closed
# 10.10.1.19:1490 -> closed
# 10.10.1.19:1491 -> closed
# 10.10.1.19:1492 -> closed
# 10.10.1.19:1493 -> closed
# 10.10.1.19:1494 -> closed
# 10.10.1.19:1495 -> closed
# 10.10.1.19:1496 -> closed
# 10.10.1.19:1497 -> closed
# 10.10.1.19:1498 -> closed
# 10.10.1.19:1499 -> closed
# 10.10.1.19:1500 -> closed
# 10.10.1.19:1501 -> closed
# 10.10.1.19:1502 -> closed
# 10.10.1.19:1503 -> closed
# 10.10.1.19:1504 -> closed
# 10.10.1.19:1505 -> closed
# 10.10.1.19:1506 -> closed
# 10.10.1.19:1507 -> closed
# 10.10.1.19:1508 -> closed
# 10.10.1.19:1509 -> closed
# 10.10.1.19:1510 -> closed
# 10.10.1.19:1511 -> closed
# 10.10.1.19:1512 -> closed
# 10.10.1.19:1513 -> closed
# 10.10.1.19:1514 -> closed
# 10.10.1.19:1515 -> closed
# 10.10.1.19:1516 -> closed
# 10.10.1.19:1517 -> closed
# 10.10.1.19:1518 -> closed
# 10.10.1.19:1519 -> closed
# 10.10.1.19:1520 -> closed
# 10.10.1.19:1521 -> closed
# 10.10.1.19:1522 -> closed
# 10.10.1.19:1523 -> closed
# 10.10.1.19:1524 -> closed
# 10.10.1.19:1525 -> closed
# 10.10.1.19:1526 -> closed
# 10.10.1.19:1527 -> closed
# 10.10.1.19:1528 -> closed
# 10.10.1.19:1529 -> closed
# 10.10.1.19:1530 -> closed
# 10.10.1.19:1531 -> closed
# 10.10.1.19:1532 -> closed
# 10.10.1.19:1533 -> closed
# 10.10.1.19:1534 -> closed
# 10.10.1.19:1535 -> closed
# 10.10.1.19:1536 -> closed
# 10.10.1.19:1537 -> closed
# 10.10.1.19:1538 -> closed
# 10.10.1.19:1539 -> closed
# 10.10.1.19:1540 -> closed
# 10.10.1.19:1541 -> closed
# 10.10.1.19:1542 -> closed
# 10.10.1.19:1543 -> closed
# 10.10.1.19:1544 -> closed
# 10.10.1.19:1545 -> closed
# 10.10.1.19:1546 -> closed
# 10.10.1.19:1547 -> closed
# 10.10.1.19:1548 -> closed
# 10.10.1.19:1549 -> closed
# 10.10.1.19:1550 -> closed
# 10.10.1.19:1551 -> closed
# 10.10.1.19:1552 -> closed
# 10.10.1.19:1553 -> closed
# 10.10.1.19:1554 -> closed
# 10.10.1.19:1555 -> closed
# 10.10.1.19:1556 -> closed
# 10.10.1.19:1557 -> closed
# 10.10.1.19:1558 -> closed
# 10.10.1.19:1559 -> closed
# 10.10.1.19:1560 -> closed
# 10.10.1.19:1561 -> closed
# 10.10.1.19:1562 -> closed
# 10.10.1.19:1563 -> closed
# 10.10.1.19:1564 -> closed
# 10.10.1.19:1565 -> closed
# 10.10.1.19:1566 -> closed
# 10.10.1.19:1567 -> closed
# 10.10.1.19:1568 -> closed
# 10.10.1.19:1569 -> closed
# 10.10.1.19:1570 -> closed
# 10.10.1.19:1571 -> closed
# 10.10.1.19:1572 -> closed
# 10.10.1.19:1573 -> closed
# 10.10.1.19:1574 -> closed
# 10.10.1.19:1575 -> closed
# 10.10.1.19:1576 -> closed
# 10.10.1.19:1577 -> closed
# 10.10.1.19:1578 -> closed
# 10.10.1.19:1579 -> closed
# 10.10.1.19:1580 -> closed
# 10.10.1.19:1581 -> closed
# 10.10.1.19:1582 -> closed
# 10.10.1.19:1583 -> closed
# 10.10.1.19:1584 -> closed
# 10.10.1.19:1585 -> closed
# 10.10.1.19:1586 -> closed
# 10.10.1.19:1587 -> closed
# 10.10.1.19:1588 -> closed
# 10.10.1.19:1589 -> closed
# 10.10.1.19:1590 -> closed
# 10.10.1.19:1591 -> closed
# 10.10.1.19:1592 -> closed
# 10.10.1.19:1593 -> closed
# 10.10.1.19:1594 -> closed
# 10.10.1.19:1595 -> closed
# 10.10.1.19:1596 -> closed
# 10.10.1.19:1597 -> closed
# 10.10.1.19:1598 -> closed
# 10.10.1.19:1599 -> closed
# 10.10.1.19:1600 -> closed
# 10.10.1.19:1601 -> closed
# 10.10.1.19:1602 -> closed
# 10.10.1.19:1603 -> closed
# 10.10.1.19:1604 -> closed
# 10.10.1.19:1605 -> closed
# 10.10.1.19:1606 -> closed
# 10.10.1.19:1607 -> closed
# 10.10.1.19:1608 -> closed
# 10.10.1.19:1609 -> closed
# 10.10.1.19:1610 -> closed
# 10.10.1.19:1611 -> closed
# 10.10.1.19:1612 -> closed
# 10.10.1.19:1613 -> closed
# 10.10.1.19:1614 -> closed
# 10.10.1.19:1615 -> closed
# 10.10.1.19:1616 -> closed
# 10.10.1.19:1617 -> closed
# 10.10.1.19:1618 -> closed
# 10.10.1.19:1619 -> closed
# 10.10.1.19:1620 -> closed
# 10.10.1.19:1621 -> closed
# 10.10.1.19:1622 -> closed
# 10.10.1.19:1623 -> closed
# 10.10.1.19:1624 -> closed
# 10.10.1.19:1625 -> closed
# 10.10.1.19:1626 -> closed
# 10.10.1.19:1627 -> closed
# 10.10.1.19:1628 -> closed
# 10.10.1.19:1629 -> closed
# 10.10.1.19:1630 -> closed
# 10.10.1.19:1631 -> closed
# 10.10.1.19:1632 -> closed
# 10.10.1.19:1633 -> closed
# 10.10.1.19:1634 -> closed
# 10.10.1.19:1635 -> closed
# 10.10.1.19:1636 -> closed
# 10.10.1.19:1637 -> closed
# 10.10.1.19:1638 -> closed
# 10.10.1.19:1639 -> closed
# 10.10.1.19:1640 -> closed
# 10.10.1.19:1641 -> closed
# 10.10.1.19:1642 -> closed
# 10.10.1.19:1643 -> closed
# 10.10.1.19:1644 -> closed
# 10.10.1.19:1645 -> closed
# 10.10.1.19:1646 -> closed
# 10.10.1.19:1647 -> closed
# 10.10.1.19:1648 -> closed
# 10.10.1.19:1649 -> closed
# 10.10.1.19:1650 -> closed
# 10.10.1.19:1651 -> closed
# 10.10.1.19:1652 -> closed
# 10.10.1.19:1653 -> closed
# 10.10.1.19:1654 -> closed
# 10.10.1.19:1655 -> closed
# 10.10.1.19:1656 -> closed
# 10.10.1.19:1657 -> closed
# 10.10.1.19:1658 -> closed
# 10.10.1.19:1659 -> closed
# 10.10.1.19:1660 -> closed
# 10.10.1.19:1661 -> closed
# 10.10.1.19:1662 -> closed
# 10.10.1.19:1663 -> closed
# 10.10.1.19:1664 -> closed
# 10.10.1.19:1665 -> closed
# 10.10.1.19:1666 -> closed
# 10.10.1.19:1667 -> closed
# 10.10.1.19:1668 -> closed
# 10.10.1.19:1669 -> closed
# 10.10.1.19:1670 -> closed
# 10.10.1.19:1671 -> closed
# 10.10.1.19:1672 -> closed
# 10.10.1.19:1673 -> closed
# 10.10.1.19:1674 -> closed
# 10.10.1.19:1675 -> closed
# 10.10.1.19:1676 -> closed
# 10.10.1.19:1677 -> closed
# 10.10.1.19:1678 -> closed
# 10.10.1.19:1679 -> closed
# 10.10.1.19:1680 -> closed
# 10.10.1.19:1681 -> closed
# 10.10.1.19:1682 -> closed
# 10.10.1.19:1683 -> closed
# 10.10.1.19:1684 -> closed
# 10.10.1.19:1685 -> closed
# 10.10.1.19:1686 -> closed
# 10.10.1.19:1687 -> closed
# 10.10.1.19:1688 -> closed
# 10.10.1.19:1689 -> closed
# 10.10.1.19:1690 -> closed
# 10.10.1.19:1691 -> closed
# 10.10.1.19:1692 -> closed
# 10.10.1.19:1693 -> closed
# 10.10.1.19:1694 -> closed
# 10.10.1.19:1695 -> closed
# 10.10.1.19:1696 -> closed
# 10.10.1.19:1697 -> closed
# 10.10.1.19:1698 -> closed
# 10.10.1.19:1699 -> closed
# 10.10.1.19:1700 -> closed
# 10.10.1.19:1701 -> closed
# 10.10.1.19:1702 -> closed
# 10.10.1.19:1703 -> closed
# 10.10.1.19:1704 -> closed
# 10.10.1.19:1705 -> closed
# 10.10.1.19:1706 -> closed
# 10.10.1.19:1707 -> closed
# 10.10.1.19:1708 -> closed
# 10.10.1.19:1709 -> closed
# 10.10.1.19:1710 -> closed
# 10.10.1.19:1711 -> closed
# 10.10.1.19:1712 -> closed
# 10.10.1.19:1713 -> closed
# 10.10.1.19:1714 -> closed
# 10.10.1.19:1715 -> closed
# 10.10.1.19:1716 -> closed
# 10.10.1.19:1717 -> closed
# 10.10.1.19:1718 -> closed
# 10.10.1.19:1719 -> closed
# 10.10.1.19:1720 -> closed
# 10.10.1.19:1721 -> closed
# 10.10.1.19:1722 -> closed
# 10.10.1.19:1723 -> closed
# 10.10.1.19:1724 -> closed
# 10.10.1.19:1725 -> closed
# 10.10.1.19:1726 -> closed
# 10.10.1.19:1727 -> closed
# 10.10.1.19:1728 -> closed
# 10.10.1.19:1729 -> closed
# 10.10.1.19:1730 -> closed
# 10.10.1.19:1731 -> closed
# 10.10.1.19:1732 -> closed
# 10.10.1.19:1733 -> closed
# 10.10.1.19:1734 -> closed
# 10.10.1.19:1735 -> closed
# 10.10.1.19:1736 -> closed
# 10.10.1.19:1737 -> closed
# 10.10.1.19:1738 -> closed
# 10.10.1.19:1739 -> closed
# 10.10.1.19:1740 -> closed
# 10.10.1.19:1741 -> closed
# 10.10.1.19:1742 -> closed
# 10.10.1.19:1743 -> closed
# 10.10.1.19:1744 -> closed
# 10.10.1.19:1745 -> closed
# 10.10.1.19:1746 -> closed
# 10.10.1.19:1747 -> closed
# 10.10.1.19:1748 -> closed
# 10.10.1.19:1749 -> closed
# 10.10.1.19:1750 -> closed
# 10.10.1.19:1751 -> closed
# 10.10.1.19:1752 -> closed
# 10.10.1.19:1753 -> closed
# 10.10.1.19:1754 -> closed
# 10.10.1.19:1755 -> closed
# 10.10.1.19:1756 -> closed
# 10.10.1.19:1757 -> closed
# 10.10.1.19:1758 -> closed
# 10.10.1.19:1759 -> closed
# 10.10.1.19:1760 -> closed
# 10.10.1.19:1761 -> closed
# 10.10.1.19:1762 -> closed
# 10.10.1.19:1763 -> closed
# 10.10.1.19:1764 -> closed
# 10.10.1.19:1765 -> closed
# 10.10.1.19:1766 -> closed
# 10.10.1.19:1767 -> closed
# 10.10.1.19:1768 -> closed
# 10.10.1.19:1769 -> closed
# 10.10.1.19:1770 -> closed
# 10.10.1.19:1771 -> closed
# 10.10.1.19:1772 -> closed
# 10.10.1.19:1773 -> closed
# 10.10.1.19:1774 -> closed
# 10.10.1.19:1775 -> closed
# 10.10.1.19:1776 -> closed
# 10.10.1.19:1777 -> closed
# 10.10.1.19:1778 -> closed
# 10.10.1.19:1779 -> closed
# 10.10.1.19:1780 -> closed
# 10.10.1.19:1781 -> closed
# 10.10.1.19:1782 -> closed
# 10.10.1.19:1783 -> closed
# 10.10.1.19:1784 -> closed
# 10.10.1.19:1785 -> closed
# 10.10.1.19:1786 -> closed
# 10.10.1.19:1787 -> closed
# 10.10.1.19:1788 -> closed
# 10.10.1.19:1789 -> closed
# 10.10.1.19:1790 -> closed
# 10.10.1.19:1791 -> closed
# 10.10.1.19:1792 -> closed
# 10.10.1.19:1793 -> closed
# 10.10.1.19:1794 -> closed
# 10.10.1.19:1795 -> closed
# 10.10.1.19:1796 -> closed
# 10.10.1.19:1797 -> closed
# 10.10.1.19:1798 -> closed
# 10.10.1.19:1799 -> closed
# 10.10.1.19:1800 -> closed
# 10.10.1.19:1801 -> closed
# 10.10.1.19:1802 -> closed
# 10.10.1.19:1803 -> closed
# 10.10.1.19:1804 -> closed
# 10.10.1.19:1805 -> closed
# 10.10.1.19:1806 -> closed
# 10.10.1.19:1807 -> closed
# 10.10.1.19:1808 -> closed
# 10.10.1.19:1809 -> closed
# 10.10.1.19:1810 -> closed
# 10.10.1.19:1811 -> closed
# 10.10.1.19:1812 -> closed
# 10.10.1.19:1813 -> closed
# 10.10.1.19:1814 -> closed
# 10.10.1.19:1815 -> closed
# 10.10.1.19:1816 -> closed
# 10.10.1.19:1817 -> closed
# 10.10.1.19:1818 -> closed
# 10.10.1.19:1819 -> closed
# 10.10.1.19:1820 -> closed
# 10.10.1.19:1821 -> closed
# 10.10.1.19:1822 -> closed
# 10.10.1.19:1823 -> closed
# 10.10.1.19:1824 -> closed
# 10.10.1.19:1825 -> closed
# 10.10.1.19:1826 -> closed
# 10.10.1.19:1827 -> closed
# 10.10.1.19:1828 -> closed
# 10.10.1.19:1829 -> closed
# 10.10.1.19:1830 -> closed
# 10.10.1.19:1831 -> closed
# 10.10.1.19:1832 -> closed
# 10.10.1.19:1833 -> closed
# 10.10.1.19:1834 -> closed
# 10.10.1.19:1835 -> closed
# 10.10.1.19:1836 -> closed
# 10.10.1.19:1837 -> closed
# 10.10.1.19:1838 -> closed
# 10.10.1.19:1839 -> closed
# 10.10.1.19:1840 -> closed
# 10.10.1.19:1841 -> closed
# 10.10.1.19:1842 -> closed
# 10.10.1.19:1843 -> closed
# 10.10.1.19:1844 -> closed
# 10.10.1.19:1845 -> closed
# 10.10.1.19:1846 -> closed
# 10.10.1.19:1847 -> closed
# 10.10.1.19:1848 -> closed
# 10.10.1.19:1849 -> closed
# 10.10.1.19:1850 -> closed
# 10.10.1.19:1851 -> closed
# 10.10.1.19:1852 -> closed
# 10.10.1.19:1853 -> closed
# 10.10.1.19:1854 -> closed
# 10.10.1.19:1855 -> closed
# 10.10.1.19:1856 -> closed
# 10.10.1.19:1857 -> closed
# 10.10.1.19:1858 -> closed
# 10.10.1.19:1859 -> closed
# 10.10.1.19:1860 -> closed
# 10.10.1.19:1861 -> closed
# 10.10.1.19:1862 -> closed
# 10.10.1.19:1863 -> closed
# 10.10.1.19:1864 -> closed
# 10.10.1.19:1865 -> closed
# 10.10.1.19:1866 -> closed
# 10.10.1.19:1867 -> closed
# 10.10.1.19:1868 -> closed
# 10.10.1.19:1869 -> closed
# 10.10.1.19:1870 -> closed
# 10.10.1.19:1871 -> closed
# 10.10.1.19:1872 -> closed
# 10.10.1.19:1873 -> closed
# 10.10.1.19:1874 -> closed
# 10.10.1.19:1875 -> closed
# 10.10.1.19:1876 -> closed
# 10.10.1.19:1877 -> closed
# 10.10.1.19:1878 -> closed
# 10.10.1.19:1879 -> closed
# 10.10.1.19:1880 -> closed
# 10.10.1.19:1881 -> closed
# 10.10.1.19:1882 -> closed
# 10.10.1.19:1883 -> closed
# 10.10.1.19:1884 -> closed
# 10.10.1.19:1885 -> closed
# 10.10.1.19:1886 -> closed
# 10.10.1.19:1887 -> closed
# 10.10.1.19:1888 -> closed
# 10.10.1.19:1889 -> closed
# 10.10.1.19:1890 -> closed
# 10.10.1.19:1891 -> closed
# 10.10.1.19:1892 -> closed
# 10.10.1.19:1893 -> closed
# 10.10.1.19:1894 -> closed
# 10.10.1.19:1895 -> closed
# 10.10.1.19:1896 -> closed
# 10.10.1.19:1897 -> closed
# 10.10.1.19:1898 -> closed
# 10.10.1.19:1899 -> closed
# 10.10.1.19:1900 -> closed
# ...
# 10.10.1.19:3064 -> closed
# 10.10.1.19:3065 -> closed
# 10.10.1.19:3066 -> closed
# 10.10.1.19:3067 -> closed
# 10.10.1.19:3068 -> closed
# 10.10.1.19:3069 -> closed
# 10.10.1.19:3070 -> closed
# 10.10.1.19:3071 -> closed
# 10.10.1.19:3072 -> closed
# 10.10.1.19:3073 -> closed
# 10.10.1.19:3074 -> closed
# 10.10.1.19:3075 -> closed
# 10.10.1.19:3076 -> closed
# 10.10.1.19:3077 -> closed
# 10.10.1.19:3078 -> closed
# 10.10.1.19:3079 -> closed
# 10.10.1.19:3080 -> closed
# 10.10.1.19:3081 -> closed
# 10.10.1.19:3082 -> closed
# 10.10.1.19:3083 -> closed
# 10.10.1.19:3084 -> closed
# 10.10.1.19:3085 -> closed
# 10.10.1.19:3086 -> closed
# 10.10.1.19:3087 -> closed
# 10.10.1.19:3088 -> closed
# 10.10.1.19:3089 -> closed
# 10.10.1.19:3090 -> closed
# 10.10.1.19:3091 -> closed
# 10.10.1.19:3092 -> closed
# 10.10.1.19:3093 -> closed
# 10.10.1.19:3094 -> closed
# 10.10.1.19:3095 -> closed
# 10.10.1.19:3096 -> closed
# 10.10.1.19:3097 -> closed
# 10.10.1.19:3098 -> closed
# 10.10.1.19:3099 -> closed
# 10.10.1.19:3100 -> closed
# 10.10.1.19:3101 -> closed
# 10.10.1.19:3102 -> closed
# 10.10.1.19:3103 -> closed
# 10.10.1.19:3104 -> closed
# 10.10.1.19:3105 -> closed
# 10.10.1.19:3106 -> closed
# 10.10.1.19:3107 -> closed
# 10.10.1.19:3108 -> closed
# 10.10.1.19:3109 -> closed
# 10.10.1.19:3110 -> closed
# 10.10.1.19:3111 -> closed
# 10.10.1.19:3112 -> closed
# 10.10.1.19:3113 -> closed
# 10.10.1.19:3114 -> closed
# 10.10.1.19:3115 -> closed
# 10.10.1.19:3116 -> closed
# 10.10.1.19:3117 -> closed
# 10.10.1.19:3118 -> closed
# 10.10.1.19:3119 -> closed
# 10.10.1.19:3120 -> closed
# 10.10.1.19:3121 -> closed
# 10.10.1.19:3122 -> closed
# 10.10.1.19:3123 -> closed
# 10.10.1.19:3124 -> closed
# 10.10.1.19:3125 -> closed
# 10.10.1.19:3126 -> closed
# 10.10.1.19:3127 -> closed
# 10.10.1.19:3128 -> closed
# 10.10.1.19:3129 -> closed
# 10.10.1.19:3130 -> closed
# 10.10.1.19:3131 -> closed
# 10.10.1.19:3132 -> closed
# 10.10.1.19:3133 -> closed
# 10.10.1.19:3134 -> closed
# 10.10.1.19:3135 -> closed
# 10.10.1.19:3136 -> closed
# 10.10.1.19:3137 -> closed
# 10.10.1.19:3138 -> closed
# 10.10.1.19:3139 -> closed
# 10.10.1.19:3140 -> closed
# 10.10.1.19:3141 -> closed
# 10.10.1.19:3142 -> closed
# 10.10.1.19:3143 -> closed
# 10.10.1.19:3144 -> closed
# 10.10.1.19:3145 -> closed
# 10.10.1.19:3146 -> closed
# 10.10.1.19:3147 -> closed
# 10.10.1.19:3148 -> closed
# 10.10.1.19:3149 -> closed
# 10.10.1.19:3150 -> closed
# 10.10.1.19:3151 -> closed
# 10.10.1.19:3152 -> closed
# 10.10.1.19:3153 -> closed
# 10.10.1.19:3154 -> closed
# 10.10.1.19:3155 -> closed
# 10.10.1.19:3156 -> closed
# 10.10.1.19:3157 -> closed
# 10.10.1.19:3158 -> closed
# 10.10.1.19:3159 -> closed
# 10.10.1.19:3160 -> closed
# 10.10.1.19:3161 -> closed
# 10.10.1.19:3162 -> closed
# 10.10.1.19:3163 -> closed
# 10.10.1.19:3164 -> closed
# 10.10.1.19:3165 -> closed
# 10.10.1.19:3166 -> closed
# 10.10.1.19:3167 -> closed
# 10.10.1.19:3168 -> closed
# 10.10.1.19:3169 -> closed
# 10.10.1.19:3170 -> closed
# 10.10.1.19:3171 -> closed
# 10.10.1.19:3172 -> closed
# 10.10.1.19:3173 -> closed
# 10.10.1.19:3174 -> closed
# 10.10.1.19:3175 -> closed
# 10.10.1.19:3176 -> closed
# 10.10.1.19:3177 -> closed
# 10.10.1.19:3178 -> closed
# 10.10.1.19:3179 -> closed
# 10.10.1.19:3180 -> closed
# 10.10.1.19:3181 -> closed
# 10.10.1.19:3182 -> closed
# 10.10.1.19:3183 -> closed
# 10.10.1.19:3184 -> closed
# 10.10.1.19:3185 -> closed
# 10.10.1.19:3186 -> closed
# 10.10.1.19:3187 -> closed
# 10.10.1.19:3188 -> closed
# 10.10.1.19:3189 -> closed
# 10.10.1.19:3190 -> closed
# 10.10.1.19:3191 -> closed
# 10.10.1.19:3192 -> closed
# 10.10.1.19:3193 -> closed
# 10.10.1.19:3194 -> closed
# 10.10.1.19:3195 -> closed
# 10.10.1.19:3196 -> closed
# 10.10.1.19:3197 -> closed
# 10.10.1.19:3198 -> closed
# 10.10.1.19:3199 -> closed
# 10.10.1.19:3200 -> closed
# 10.10.1.19:3201 -> closed
# 10.10.1.19:3202 -> closed
# 10.10.1.19:3203 -> closed
# 10.10.1.19:3204 -> closed
# 10.10.1.19:3205 -> closed
# 10.10.1.19:3206 -> closed
# 10.10.1.19:3207 -> closed
# 10.10.1.19:3208 -> closed
# 10.10.1.19:3209 -> closed
# 10.10.1.19:3210 -> closed
# 10.10.1.19:3211 -> closed
# 10.10.1.19:3212 -> closed
# 10.10.1.19:3213 -> closed
# 10.10.1.19:3214 -> closed
# 10.10.1.19:3215 -> closed
# 10.10.1.19:3216 -> closed
# 10.10.1.19:3217 -> closed
# 10.10.1.19:3218 -> closed
# 10.10.1.19:3219 -> closed
# 10.10.1.19:3220 -> closed
# 10.10.1.19:3221 -> closed
# 10.10.1.19:3222 -> closed
# 10.10.1.19:3223 -> closed
# 10.10.1.19:3224 -> closed
# 10.10.1.19:3225 -> closed
# 10.10.1.19:3226 -> closed
# 10.10.1.19:3227 -> closed
# 10.10.1.19:3228 -> closed
# 10.10.1.19:3229 -> closed
# 10.10.1.19:3230 -> closed
# 10.10.1.19:3231 -> closed
# 10.10.1.19:3232 -> closed
# 10.10.1.19:3233 -> closed
# 10.10.1.19:3234 -> closed
# 10.10.1.19:3235 -> closed
# 10.10.1.19:3236 -> closed
# 10.10.1.19:3237 -> closed
# 10.10.1.19:3238 -> closed
# 10.10.1.19:3239 -> closed
# 10.10.1.19:3240 -> closed
# 10.10.1.19:3241 -> closed
# 10.10.1.19:3242 -> closed
# 10.10.1.19:3243 -> closed
# 10.10.1.19:3244 -> closed
# 10.10.1.19:3245 -> closed
# 10.10.1.19:3246 -> closed
# 10.10.1.19:3247 -> closed
# 10.10.1.19:3248 -> closed
# 10.10.1.19:3249 -> closed
# 10.10.1.19:3250 -> closed
# 10.10.1.19:3251 -> closed
# 10.10.1.19:3252 -> closed
# 10.10.1.19:3253 -> closed
# 10.10.1.19:3254 -> closed
# 10.10.1.19:3255 -> closed
# 10.10.1.19:3256 -> closed
# 10.10.1.19:3257 -> closed
# 10.10.1.19:3258 -> closed
# 10.10.1.19:3259 -> closed
# 10.10.1.19:3260 -> closed
# 10.10.1.19:3261 -> closed
# 10.10.1.19:3262 -> closed
# 10.10.1.19:3263 -> closed
# 10.10.1.19:3264 -> closed
# 10.10.1.19:3265 -> closed
# 10.10.1.19:3266 -> closed
# 10.10.1.19:3267 -> closed
# 10.10.1.19:3268 -> closed
# 10.10.1.19:3269 -> closed
# 10.10.1.19:3270 -> closed
# 10.10.1.19:3271 -> closed
# 10.10.1.19:3272 -> closed
# 10.10.1.19:3273 -> closed
# 10.10.1.19:3274 -> closed
# 10.10.1.19:3275 -> closed
# 10.10.1.19:3276 -> closed
# 10.10.1.19:3277 -> closed
# 10.10.1.19:3278 -> closed
# 10.10.1.19:3279 -> closed
# 10.10.1.19:3280 -> closed
# 10.10.1.19:3281 -> closed
# 10.10.1.19:3282 -> closed
# 10.10.1.19:3283 -> closed
# 10.10.1.19:3284 -> closed
# 10.10.1.19:3285 -> closed
# 10.10.1.19:3286 -> closed
# 10.10.1.19:3287 -> closed
# 10.10.1.19:3288 -> closed
# 10.10.1.19:3289 -> closed
# 10.10.1.19:3290 -> closed
# 10.10.1.19:3291 -> closed
# 10.10.1.19:3292 -> closed
# 10.10.1.19:3293 -> closed
# 10.10.1.19:3294 -> closed
# 10.10.1.19:3295 -> closed
# 10.10.1.19:3296 -> closed
# 10.10.1.19:3297 -> closed
# 10.10.1.19:3298 -> closed
# 10.10.1.19:3299 -> closed
# 10.10.1.19:3300 -> closed
# 10.10.1.19:3301 -> closed
# 10.10.1.19:3302 -> closed
# 10.10.1.19:3303 -> closed
# 10.10.1.19:3304 -> closed
# 10.10.1.19:3305 -> closed
# 10.10.1.19:3306 -> closed
# 10.10.1.19:3307 -> closed
# 10.10.1.19:3308 -> closed
# 10.10.1.19:3309 -> closed
# 10.10.1.19:3310 -> closed
# 10.10.1.19:3311 -> closed
# 10.10.1.19:3312 -> closed
# 10.10.1.19:3313 -> closed
# 10.10.1.19:3314 -> closed
# 10.10.1.19:3315 -> closed
# 10.10.1.19:3316 -> closed
# 10.10.1.19:3317 -> closed
# 10.10.1.19:3318 -> closed
# 10.10.1.19:3319 -> closed
# 10.10.1.19:3320 -> closed
# 10.10.1.19:3321 -> closed
# 10.10.1.19:3322 -> closed
# 10.10.1.19:3323 -> closed
# 10.10.1.19:3324 -> closed
# 10.10.1.19:3325 -> closed
# 10.10.1.19:3326 -> closed
# 10.10.1.19:3327 -> closed
# 10.10.1.19:3328 -> closed
# 10.10.1.19:3329 -> closed
# 10.10.1.19:3330 -> closed
# 10.10.1.19:3331 -> closed
# 10.10.1.19:3332 -> closed
# 10.10.1.19:3333 -> closed
# 10.10.1.19:3334 -> closed
# 10.10.1.19:3335 -> closed
# 10.10.1.19:3336 -> closed
# 10.10.1.19:3337 -> closed
# 10.10.1.19:3338 -> closed
# 10.10.1.19:3339 -> closed
# 10.10.1.19:3340 -> closed
# 10.10.1.19:3341 -> closed
# 10.10.1.19:3342 -> closed
# 10.10.1.19:3343 -> closed
# 10.10.1.19:3344 -> closed
# 10.10.1.19:3345 -> closed
# 10.10.1.19:3346 -> closed
# 10.10.1.19:3347 -> closed
# 10.10.1.19:3348 -> closed
# 10.10.1.19:3349 -> closed
# 10.10.1.19:3350 -> closed
# 10.10.1.19:3351 -> closed
# 10.10.1.19:3352 -> closed
# 10.10.1.19:3353 -> closed
# 10.10.1.19:3354 -> closed
# 10.10.1.19:3355 -> closed
# 10.10.1.19:3356 -> closed
# 10.10.1.19:3357 -> closed
# 10.10.1.19:3358 -> closed
# 10.10.1.19:3359 -> closed
# 10.10.1.19:3360 -> closed
# 10.10.1.19:3361 -> closed
# 10.10.1.19:3362 -> closed
# 10.10.1.19:3363 -> closed
# 10.10.1.19:3364 -> closed
# 10.10.1.19:3365 -> closed
# 10.10.1.19:3366 -> closed
# 10.10.1.19:3367 -> closed
# 10.10.1.19:3368 -> closed
# 10.10.1.19:3369 -> closed
# 10.10.1.19:3370 -> closed
# 10.10.1.19:3371 -> closed
# 10.10.1.19:3372 -> closed
# 10.10.1.19:3373 -> closed
# 10.10.1.19:3374 -> closed
# 10.10.1.19:3375 -> closed
# 10.10.1.19:3376 -> closed
# 10.10.1.19:3377 -> closed
# 10.10.1.19:3378 -> closed
# 10.10.1.19:3379 -> closed
# 10.10.1.19:3380 -> closed
# 10.10.1.19:3381 -> closed
# 10.10.1.19:3382 -> closed
# 10.10.1.19:3383 -> closed
# 10.10.1.19:3384 -> closed
# 10.10.1.19:3385 -> closed
# 10.10.1.19:3386 -> closed
# 10.10.1.19:3387 -> closed
# 10.10.1.19:3388 -> closed
# 10.10.1.19:3389 -> closed
# 10.10.1.19:3390 -> closed
# 10.10.1.19:3391 -> closed
# 10.10.1.19:3392 -> closed
# 10.10.1.19:3393 -> closed
# 10.10.1.19:3394 -> closed
# 10.10.1.19:3395 -> closed
# 10.10.1.19:3396 -> closed
# 10.10.1.19:3397 -> closed
# 10.10.1.19:3398 -> closed
# 10.10.1.19:3399 -> closed
# 10.10.1.19:3400 -> closed
# 10.10.1.19:3401 -> closed
# 10.10.1.19:3402 -> closed
# 10.10.1.19:3403 -> closed
# 10.10.1.19:3404 -> closed
# 10.10.1.19:3405 -> closed
# 10.10.1.19:3406 -> closed
# 10.10.1.19:3407 -> closed
# 10.10.1.19:3408 -> closed
# 10.10.1.19:3409 -> closed
# 10.10.1.19:3410 -> closed
# 10.10.1.19:3411 -> closed
# 10.10.1.19:3412 -> closed
# 10.10.1.19:3413 -> closed
# 10.10.1.19:3414 -> closed
# 10.10.1.19:3415 -> closed
# 10.10.1.19:3416 -> closed
# 10.10.1.19:3417 -> closed
# 10.10.1.19:3418 -> closed
# 10.10.1.19:3419 -> closed
# 10.10.1.19:3420 -> closed
# 10.10.1.19:3421 -> closed
# 10.10.1.19:3422 -> closed
# 10.10.1.19:3423 -> closed
# 10.10.1.19:3424 -> closed
# 10.10.1.19:3425 -> closed
# 10.10.1.19:3426 -> closed
# 10.10.1.19:3427 -> closed
# 10.10.1.19:3428 -> closed
# 10.10.1.19:3429 -> closed
# 10.10.1.19:3430 -> closed
# 10.10.1.19:3431 -> closed
# 10.10.1.19:3432 -> closed
# 10.10.1.19:3433 -> closed
# 10.10.1.19:3434 -> closed
# 10.10.1.19:3435 -> closed
# 10.10.1.19:3436 -> closed
# 10.10.1.19:3437 -> closed
# 10.10.1.19:3438 -> closed
# 10.10.1.19:3439 -> closed
# 10.10.1.19:3440 -> closed
# 10.10.1.19:3441 -> closed
# 10.10.1.19:3442 -> closed
# 10.10.1.19:3443 -> closed
# 10.10.1.19:3444 -> closed
# 10.10.1.19:3445 -> closed
# 10.10.1.19:3446 -> closed
# 10.10.1.19:3447 -> closed
# 10.10.1.19:3448 -> closed
# 10.10.1.19:3449 -> closed
# 10.10.1.19:3450 -> closed
# 10.10.1.19:3451 -> closed
# 10.10.1.19:3452 -> closed
# 10.10.1.19:3453 -> closed
# 10.10.1.19:3454 -> closed
# 10.10.1.19:3455 -> closed
# 10.10.1.19:3456 -> closed
# 10.10.1.19:3457 -> closed
# 10.10.1.19:3458 -> closed
# 10.10.1.19:3459 -> closed
# 10.10.1.19:3460 -> closed
# 10.10.1.19:3461 -> closed
# 10.10.1.19:3462 -> closed
# 10.10.1.19:3463 -> closed
# 10.10.1.19:3464 -> closed
# 10.10.1.19:3465 -> closed
# 10.10.1.19:3466 -> closed
# 10.10.1.19:3467 -> closed
# 10.10.1.19:3468 -> closed
# 10.10.1.19:3469 -> closed
# 10.10.1.19:3470 -> closed
# 10.10.1.19:3471 -> closed
# 10.10.1.19:3472 -> closed
# 10.10.1.19:3473 -> closed
# 10.10.1.19:3474 -> closed
# 10.10.1.19:3475 -> closed
# 10.10.1.19:3476 -> closed
# 10.10.1.19:3477 -> closed
# 10.10.1.19:3478 -> closed
# 10.10.1.19:3479 -> closed
# 10.10.1.19:3480 -> closed
# 10.10.1.19:3481 -> closed
# 10.10.1.19:3482 -> closed
# 10.10.1.19:3483 -> closed
# 10.10.1.19:3484 -> closed
# 10.10.1.19:3485 -> closed
# 10.10.1.19:3486 -> closed
# 10.10.1.19:3487 -> closed
# 10.10.1.19:3488 -> closed
# 10.10.1.19:3489 -> closed
# 10.10.1.19:3490 -> closed
# 10.10.1.19:3491 -> closed
# 10.10.1.19:3492 -> closed
# 10.10.1.19:3493 -> closed
# 10.10.1.19:3494 -> closed
# 10.10.1.19:3495 -> closed
# 10.10.1.19:3496 -> closed
# 10.10.1.19:3497 -> closed
# 10.10.1.19:3498 -> closed
# 10.10.1.19:3499 -> closed
# 10.10.1.19:3500 -> closed
# 10.10.1.19:3501 -> closed
# 10.10.1.19:3502 -> closed
# 10.10.1.19:3503 -> closed
# 10.10.1.19:3504 -> closed
# 10.10.1.19:3505 -> closed
# 10.10.1.19:3506 -> closed
# 10.10.1.19:3507 -> closed
# 10.10.1.19:3508 -> closed
# 10.10.1.19:3509 -> closed
# 10.10.1.19:3510 -> closed
# 10.10.1.19:3511 -> closed
# 10.10.1.19:3512 -> closed
# 10.10.1.19:3513 -> closed
# 10.10.1.19:3514 -> closed
# 10.10.1.19:3515 -> closed
# 10.10.1.19:3516 -> closed
# 10.10.1.19:3517 -> closed
# 10.10.1.19:3518 -> closed
# 10.10.1.19:3519 -> closed
# 10.10.1.19:3520 -> closed
# 10.10.1.19:3521 -> closed
# 10.10.1.19:3522 -> closed
# 10.10.1.19:3523 -> closed
# 10.10.1.19:3524 -> closed
# 10.10.1.19:3525 -> closed
# 10.10.1.19:3526 -> closed
# 10.10.1.19:3527 -> closed
# 10.10.1.19:3528 -> closed
# 10.10.1.19:3529 -> closed
# 10.10.1.19:3530 -> closed
# 10.10.1.19:3531 -> closed
# 10.10.1.19:3532 -> closed
# 10.10.1.19:3533 -> closed
# 10.10.1.19:3534 -> closed
# 10.10.1.19:3535 -> closed
# 10.10.1.19:3536 -> closed
# 10.10.1.19:3537 -> closed
# 10.10.1.19:3538 -> closed
# 10.10.1.19:3539 -> closed
# 10.10.1.19:3540 -> closed
# 10.10.1.19:3541 -> closed
# 10.10.1.19:3542 -> closed
# 10.10.1.19:3543 -> closed
# 10.10.1.19:3544 -> closed
# 10.10.1.19:3545 -> closed
# 10.10.1.19:3546 -> closed
# 10.10.1.19:3547 -> closed
# 10.10.1.19:3548 -> closed
# 10.10.1.19:3549 -> closed
# 10.10.1.19:3550 -> closed
# 10.10.1.19:3551 -> closed
# 10.10.1.19:3552 -> closed
# 10.10.1.19:3553 -> closed
# 10.10.1.19:3554 -> closed
# 10.10.1.19:3555 -> closed
# 10.10.1.19:3556 -> closed
# 10.10.1.19:3557 -> closed
# 10.10.1.19:3558 -> closed
# 10.10.1.19:3559 -> closed
# 10.10.1.19:3560 -> closed
# 10.10.1.19:3561 -> closed
# 10.10.1.19:3562 -> closed
# 10.10.1.19:3563 -> closed
# 10.10.1.19:3564 -> closed
# 10.10.1.19:3565 -> closed
# 10.10.1.19:3566 -> closed
# 10.10.1.19:3567 -> closed
# 10.10.1.19:3568 -> closed
# 10.10.1.19:3569 -> closed
# 10.10.1.19:3570 -> closed
# 10.10.1.19:3571 -> closed
# 10.10.1.19:3572 -> closed
# 10.10.1.19:3573 -> closed
# 10.10.1.19:3574 -> closed
# 10.10.1.19:3575 -> closed
# 10.10.1.19:3576 -> closed
# 10.10.1.19:3577 -> closed
# 10.10.1.19:3578 -> closed
# 10.10.1.19:3579 -> closed
# 10.10.1.19:3580 -> closed
# 10.10.1.19:3581 -> closed
# 10.10.1.19:3582 -> closed
# 10.10.1.19:3583 -> closed
# 10.10.1.19:3584 -> closed
# 10.10.1.19:3585 -> closed
# 10.10.1.19:3586 -> closed
# 10.10.1.19:3587 -> closed
# 10.10.1.19:3588 -> closed
# 10.10.1.19:3589 -> closed
# 10.10.1.19:3590 -> closed
# 10.10.1.19:3591 -> closed
# 10.10.1.19:3592 -> closed
# 10.10.1.19:3593 -> closed
# 10.10.1.19:3594 -> closed
# 10.10.1.19:3595 -> closed
# 10.10.1.19:3596 -> closed
# 10.10.1.19:3597 -> closed
# 10.10.1.19:3598 -> closed
# 10.10.1.19:3599 -> closed
# 10.10.1.19:3600 -> closed
# 10.10.1.19:3601 -> closed
# 10.10.1.19:3602 -> closed
# 10.10.1.19:3603 -> closed
# 10.10.1.19:3604 -> closed
# 10.10.1.19:3605 -> closed
# 10.10.1.19:3606 -> closed
# 10.10.1.19:3607 -> closed
# 10.10.1.19:3608 -> closed
# 10.10.1.19:3609 -> closed
# 10.10.1.19:3610 -> closed
# 10.10.1.19:3611 -> closed
# 10.10.1.19:3612 -> closed
# 10.10.1.19:3613 -> closed
# 10.10.1.19:3614 -> closed
# 10.10.1.19:3615 -> closed
# 10.10.1.19:3616 -> closed
# 10.10.1.19:3617 -> closed
# 10.10.1.19:3618 -> closed
# 10.10.1.19:3619 -> closed
# 10.10.1.19:3620 -> closed
# 10.10.1.19:3621 -> closed
# 10.10.1.19:3622 -> closed
# 10.10.1.19:3623 -> closed
# 10.10.1.19:3624 -> closed
# 10.10.1.19:3625 -> closed
# 10.10.1.19:3626 -> closed
# 10.10.1.19:3627 -> closed
# 10.10.1.19:3628 -> closed
# 10.10.1.19:3629 -> closed
# 10.10.1.19:3630 -> closed
# 10.10.1.19:3631 -> closed
# 10.10.1.19:3632 -> closed
# 10.10.1.19:3633 -> closed
# 10.10.1.19:3634 -> closed
# 10.10.1.19:3635 -> closed
# 10.10.1.19:3636 -> closed
# 10.10.1.19:3637 -> closed
# 10.10.1.19:3638 -> closed
# 10.10.1.19:3639 -> closed
# 10.10.1.19:3640 -> closed
# 10.10.1.19:3641 -> closed
# 10.10.1.19:3642 -> closed
# 10.10.1.19:3643 -> closed
# 10.10.1.19:3644 -> closed
# 10.10.1.19:3645 -> closed
# 10.10.1.19:3646 -> closed
# 10.10.1.19:3647 -> closed
# 10.10.1.19:3648 -> closed
# 10.10.1.19:3649 -> closed
# 10.10.1.19:3650 -> closed
# 10.10.1.19:3651 -> closed
# 10.10.1.19:3652 -> closed
# 10.10.1.19:3653 -> closed
# 10.10.1.19:3654 -> closed
# 10.10.1.19:3655 -> closed
# 10.10.1.19:3656 -> closed
# 10.10.1.19:3657 -> closed
# 10.10.1.19:3658 -> closed
# 10.10.1.19:3659 -> closed
# 10.10.1.19:3660 -> closed
# 10.10.1.19:3661 -> closed
# 10.10.1.19:3662 -> closed
# 10.10.1.19:3663 -> closed
# 10.10.1.19:3664 -> closed
# 10.10.1.19:3665 -> closed
# 10.10.1.19:3666 -> closed
# 10.10.1.19:3667 -> closed
# 10.10.1.19:3668 -> closed
# 10.10.1.19:3669 -> closed
# 10.10.1.19:3670 -> closed
# 10.10.1.19:3671 -> closed
# 10.10.1.19:3672 -> closed
# 10.10.1.19:3673 -> closed
# 10.10.1.19:3674 -> closed
# 10.10.1.19:3675 -> closed
# 10.10.1.19:3676 -> closed
# 10.10.1.19:3677 -> closed
# 10.10.1.19:3678 -> closed

# %% [markdown]
# ## 2.8 Commit, Push, Preview Day 3  *(15 min)*
#
# **Objective:** Close the day with version control and a look ahead to DFIR work.
#
# **Steps:**
#
# 1. Stage, commit, and push the chosen tool.
# 2. Read ahead: Day 3's forensics work builds directly on today's hashing and OS-interaction skills.

# %% [markdown]
# ```bash
# git add .
# git commit -m "Add Day 2 security tool"
# git push
# ```

# %% [markdown]
# ## 2.9 Exercises — On Your Own
#
# New problems, separate from the build lab above. Use the techniques from section 2.2 (`requests`, `csv.DictReader`, `Counter`, `hashlib`, `socket`). No worked example to copy from this time.
#
# > Do these after the build lab, as homework, or as a fast-finisher extension.

# %% [markdown]
# **Exercise 1 — JSON field extraction.** `GET https://httpbin.org/uuid` returns a JSON body like `{"uuid": "..."}`. Make the request, parse the JSON with `response.json()` (instead of slicing `response.text`), and print just the `uuid` value.

# %%
import requests  # Third-party HTTP library for making network requests

# Exercise 1: Fetch JSON data and extract a specific field
url = "https://httpbin.org/uuid"

# Issue an HTTP GET request to the target endpoint
response = requests.get(url)

# Parse the JSON response body directly into a Python dictionary
# This is much safer and cleaner than slicing raw text
data = response.json()

# Extract and print the specific unique identifier (UUID)
print("Extracted UUID:", data["uuid"])
# Out:
# Extracted UUID: 22230af5-6968-4182-bfe3-82b804a39b80

# %% [markdown]
# **Exercise 2 — Top talker by bytes.** Using `exercise_connections.csv` (generated below), find the `src_ip` with the highest *total* `bytes` transferred, not just the most connections. *Hint: `Counter` supports addition via indexing — `counts[key] += int(value)` — it isn't only for counting occurrences.*

# %%
# Setup: a fresh connections CSV for this exercise
exercise_connections_csv = """timestamp,src_ip,dst_port,protocol,bytes
2026-03-02T11:00:01,10.2.0.5,443,tcp,4000
2026-03-02T11:00:04,10.2.0.6,53,udp,120
2026-03-02T11:00:09,10.2.0.5,443,tcp,6500
2026-03-02T11:00:15,10.2.0.7,8080,tcp,300
2026-03-02T11:00:22,10.2.0.6,53,udp,90
2026-03-02T11:00:30,10.2.0.5,443,tcp,2200
""" 

with open("exercise_connections.csv", "w") as f: 
    f.write(exercise_connections_csv) 

import csv 
from collections import Counter 

# Exercise 2: find the src_ip with the highest total bytes transferred
byte_tally = Counter()

with open("exercise_connections.csv", "r") as file:
    reader = csv.DictReader(file)
    for row in reader:
        # We must cast row["bytes"] to an integer to perform addition
        byte_tally[row["src_ip"]] += int(row["bytes"])

# Extract the top talker and their total bytes
top_ip, total_bytes = byte_tally.most_common(1)[0]

print(f"Top talker IP: {top_ip}")
print(f"Total bytes transferred: {total_bytes}")
# Out:
# Top talker IP: 10.2.0.5
# Total bytes transferred: 12700

# %% [markdown]
# **Exercise 3 — Stretch: combine hashing and a port check.** Write a function `quick_check(path, host, port)` that returns a dict with two keys: `"sha256"` (the file's hash) and `"port_status"` (`"open"` or `"closed"`, reusing the `port_status()` pattern from section 2.2, technique 8). Call it on `sample_file.txt` against `127.0.0.1` port `22`, and print the result.

# %%
import hashlib
import socket
import os

# Exercise 3: Implement a function returning both file hash and port status[cite: 1]

def quick_check(path, host, port):
    """Return a dictionary containing the file's SHA-256 hash and the target's port status.[cite: 1]"""
    
    # 1. Compute the SHA-256 cryptographic hash of the specified file
    with open(path, "rb") as f:
        file_hash = hashlib.sha256(f.read()).hexdigest()
        
    # 2. Perform a TCP connection test to verify the port status
    sock = socket.socket(socket.AF_INET, socket.SOCK_STREAM)
    sock.settimeout(0.5)  # Cap the wait time to prevent the script from hanging
    result = sock.connect_ex((host, port))
    sock.close()  # Always release network resources
    
    # Translate the result code into a human-readable security status
    port_status = "open" if result == 0 else "closed"
    
    # 3. Return the combined intelligence data as a structured dictionary
    return {
        "sha256": file_hash,
        "port_status": port_status
    }

# Setup: Ensure the sample file exists before running the check
if not os.path.exists("sample_file.txt"):
    with open("sample_file.txt", "w") as f:
        f.write("Dummy content for the quick check exercise.\n")

# Execute the function against localhost (127.0.0.1) on port 22 (SSH)[cite: 1]
report = quick_check("sample_file.txt", "127.0.0.1", 22)

# Output the final structured report
print("Quick Check Report:", report)
# Out:
# Quick Check Report: {'sha256': '07a2b73c916791807f45ca6aa40cd1b8ed96b2439e31a47f793e0bdc45976f01', 'port_status': 'closed'}
